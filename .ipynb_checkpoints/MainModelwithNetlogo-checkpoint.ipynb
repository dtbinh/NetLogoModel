# %%
# import functions
import pandas as pd
import numpy as np
import codecs
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler                 #normalising features
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.pipeline import make_pipeline
from sklearn.cross_validation import KFold

from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import Lasso
from sklearn.svm import SVC, SVR

from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sknn import mlp

from scipy.optimize import minimize

import theano
import theano.tensor as T

# %matplotlib inline

np.random.seed=10

# %%
import matplotlib.pyplot as plt

from py4j.java_gateway import JavaGateway

# %%
# %matplotlib inline

# %% [markdown]
# # set up connection

# %%
gw = JavaGateway() # New gateway connection
bridge = gw.entry_point

# %% [markdown]
# # load netlogo model

# %%
# Path to the model:
models_path = "D:/Work/PhD/Github/NetLogoModel/"
model_name = "PhD_InitialModelV2.nlogo"

# %%
modelLocation = models_path + model_name

# %%
bridge.openModel(modelLocation)

# %% [markdown]
# # Run one iteration of the model, one command at a time:

# %%
bridge.command("set grid-size 21")
bridge.command("set nb-people 1")
bridge.command("set Show_Names_Nodes? False")
bridge.command("set Show_Names_people? False")
bridge.command("set car-speed 1")
bridge.command("set mobiletowerdata? True")
bridge.command("set socialmedia_data? True")
bridge.command("set grids_covered_vector 5")
bridge.command("set avg_num_calls_perday 5")
bridge.command("set avg_call_duration_mins 2")

bridge.command("random-seed 0")
bridge.command("setup")
bridge.command("repeat 14400 [go]")

# %%
bridge.command("repeat 1440 [go]")

# %% [markdown]
# # Have the model report results

# %%
# !head -n 15 ./agentdata.txt
# Out:
#  0 0 0 441 15 0 30 -37 453
#  1 0 1 441 15 0 30 -37 453
#  2 0 2 441 15 0 30 -37 453
#  3 0 3 441 15 0 30 -37 453
#  4 0 4 441 15 0 30 -37 453
#  5 0 5 441 15 0 30 -37 453
#  6 0 6 441 15 0 30 -37 453
#  7 0 7 441 15 0 30 -37 453
#  8 0 8 441 15 0 30 -37 453
#  9 0 9 441 15 0 30 -37 453
#  10 0 10 441 15 0 30 -37 453
#  11 0 11 441 15 0 30 -37 453
#  12 0 12 441 15 0 30 -37 453
#  13 0 13 441 15 0 30 -37 453
#  14 0 14 441 15 0 30 -37 453

# %%
# !head -n 15 ./mobiletowers.txt
# Out:
#  406 0 406 441 0 15 9.523809523809524 453 32 -32
#  804 0 804 441 0 35 9.523809523809524 454 32 16
#  1024 0 1024 441 0 25 9.523809523809524 470 -32 16
#  1898 1 458 441 0 15 9.523809523809524 453 32 -32
#  2387 1 947 441 0 25 9.523809523809524 470 -32 16
#  2436 1 996 441 0 25 9.523809523809524 470 -32 16
#  2586 1 1146 441 0 15 9.523809523809524 457 0 -16
#  3065 2 185 441 0 15 9.523809523809524 453 32 -32
#  4084 2 1204 441 0 15 9.523809523809524 453 32 -32
#  4375 3 55 441 0 15 9.523809523809524 453 32 -32
#  4687 3 367 441 0 15 9.523809523809524 453 32 -32
#  4767 3 447 441 0 15 9.523809523809524 453 32 -32
#  4813 3 493 441 0 15 9.523809523809524 453 32 -32
#  4875 3 555 441 0 25 9.523809523809524 465 0 16
#  4941 3 621 441 0 25 9.523809523809524 470 -32 16

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %%
# import simuated data
# using function as the file can be closed automatically
def rawimport(path, columnname):
    agentdata = pd.read_csv(path, delimiter=' ', header=None, names=columnname)
    agentdata = agentdata.drop(labels="todrop", axis=1)
    return agentdata
#mobiledata = pd.read_csv('./mobiletowers.txt', delimiter=' ', header=None, names=["todrop", "acc_time", "day", "minute", "pid", 
#                                                                                  "tpid", "zone", "radius", "tid", "xcor", "ycor"] )
#aa.drop(labels="todrop", axis=1)

# %%
path = './agentdata.txt'
columnname = ["todrop", "acc_time", "day", "minute", "pid", "zone", "status", "xcor", "ycor", "tid"]
agentdata = rawimport(path, columnname)

# %%
path = './mobiletowers.txt'
columnname = ["todrop", "acc_time", "day", "minute", "pid", "tpid", "tzone", "radius", "tid", "txcor", "tycor"]
mobiledata = rawimport(path, columnname)

# %%
# extend data to full (missing data shown as NaN)

mobiledata = mobiledata.drop(labels = ["tid"], axis=1)

mobiledata_fs = pd.merge(agentdata, mobiledata, how = 'left', on = ["acc_time", 'day', 'minute', "pid"])
#mobiledata_fs = pd.merge(agentdata_ri, mobiledata_ri, how = 'left', left_index = True, right_index = True)
print mobiledata_fs.count()
mobiledata_fs
# Out:
# acc_time    14400
# day         14400
# minute      14400
# pid         14400
# zone        14400
# status      14400
# xcor        14400
# ycor        14400
# tid         13946
# tpid           52
# tzone          52
# radius         52
# txcor          52
# tycor          52
# dtype: int64
#        acc_time  day  minute  pid  zone  status       xcor       ycor  tid  \
# 0             0    0       0  441    15       0  30.000000 -37.000000  453
# 1             1    0       1  441    15       0  30.000000 -37.000000  453
# 2             2    0       2  441    15       0  30.000000 -37.000000  453
# 3             3    0       3  441    15       0  30.000000 -37.000000  453
# 4             4    0       4  441    15       0  30.000000 -37.000000  453
# 5             5    0       5  441    15       0  30.000000 -37.000000  453
# 6             6    0       6  441    15       0  30.000000 -37.000000  453
# 7             7    0       7  441    15       0  30.000000 -37.000000  453
# 8             8    0       8  441    15       0  30.000000 -37.000000  453
# 9             9    0       9  441    15       0  30.000000 -37.000000  453
# 10           10    0      10  441    15       0  30.000000 -37.000000  453
# 11           11    0      11  441    15       0  30.000000 -37.000000  453
# 12           12    0      12  441    15       0  30.000000 -37.000000  453
# 13           13    0      13  441    15       0  30.000000 -37.000000  453
# 14           14    0      14  441    15       0  30.000000 -37.000000  453
# 15           15    0      15  441    15       0  30.000000 -37.000000  453
# 16           16    0      16  441    15       0  30.000000 -37.000000  453
# 17           17    0      17  441    15       0  30.000000 -37.000000  453
# 18           18    0      18  441    15       0  30.000000 -37.000000  453
# 19           19    0      19  441    15       0  30.000000 -37.000000  453
# 20           20    0      20  441    15       0  30.000000 -37.000000  453
# 21           21    0      21  441    15       0  30.000000 -37.000000  453
# 22           22    0      22  441    15       0  30.000000 -37.000000  453
# 23           23    0      23  441    15       0  30.000000 -37.000000  453
# 24           24    0      24  441    15       0  30.000000 -37.000000  453
# 25           25    0      25  441    15       0  30.000000 -37.000000  453
# 26           26    0      26  441    15       0  30.000000 -37.000000  453
# 27           27    0      27  441    15       0  30.000000 -37.000000  453
# 28           28    0      28  441    15       0  30.000000 -37.000000  453
# 29           29    0      29  441    15       0  30.000000 -37.000000  453
# ...         ...  ...     ...  ...   ...     ...        ...        ...  ...
# 14370     14370    9    1410  441    15       0  29.359114 -37.320443  453
# 14371     14371    9    1411  441    15       0  29.359114 -37.320443  453
# 14372     14372    9    1412  441    15       0  29.359114 -37.320443  453
# 14373     14373    9    1413  441    15       0  29.359114 -37.320443  453
# 14374     14374    9    1414  441    15       0  29.359114 -37.320443  453
# 14375     14375    9    1415  441    15       0  29.359114 -37.320443  453
# 14376     14376    9    1416  441    15       0  29.359114 -37.320443  453
# 14377     14377    9    1417  441    15       0  29.359114 -37.320443  453
# 14378     14378    9    1418  441    15       0  29.359114 -37.320443  453
# 14379     14379    9    1419  441    15       0  29.359114 -37.320443  453
# 14380     14380    9    1420  441    15       0  29.359114 -37.320443  453
# 14381     14381    9    1421  441    15       0  29.359114 -37.320443  453
# 14382     14382    9    1422  441    15       0  29.359114 -37.320443  453
# 14383     14383    9    1423  441    15       0  29.359114 -37.320443  453
# 14384     14384    9    1424  441    15       0  29.359114 -37.320443  453
# 14385     14385    9    1425  441    15       0  29.359114 -37.320443  453
# 14386     14386    9    1426  441    15       0  29.359114 -37.320443  453
# 14387     14387    9    1427  441    15       0  29.359114 -37.320443  453
# 14388     14388    9    1428  441    15       0  29.359114 -37.320443  453
# 14389     14389    9    1429  441    15       0  29.359114 -37.320443  453
# 14390     14390    9    1430  441    15       0  29.359114 -37.320443  453
# 14391     14391    9    1431  441    15       0  29.359114 -37.320443  453
# 14392     14392    9    1432  441    15       0  29.359114 -37.320443  453
# 14393     14393    9    1433  441    15       0  29.359114 -37.320443  453
# 14394     14394    9    1434  441    15       0  29.359114 -37.320443  453
# 14395     14395    9    1435  441    15       0  29.359114 -37.320443  453
# 14396     14396    9    1436  441    15       0  29.359114 -37.320443  453
# 14397     14397    9    1437  441    15       0  29.359114 -37.320443  453
# 14398     14398    9    1438  441    15       0  29.359114 -37.320443  453
# 14399     14399    9    1439  441    15       0  29.359114 -37.320443  453
#
#        tpid  tzone  radius  txcor  tycor
# 0       NaN    NaN     NaN    NaN    NaN
# 1       NaN    NaN     NaN    NaN    NaN
# 2       NaN    NaN     NaN    NaN    NaN
# 3       NaN    NaN     NaN    NaN    NaN
# 4       NaN    NaN     NaN    NaN    NaN
# 5       NaN    NaN     NaN    NaN    NaN
# 6       NaN    NaN     NaN    NaN    NaN
# 7       NaN    NaN     NaN    NaN    NaN
# 8       NaN    NaN     NaN    NaN    NaN
# 9       NaN    NaN     NaN    NaN    NaN
# 10      NaN    NaN     NaN    NaN    NaN
# 11      NaN    NaN     NaN    NaN    NaN
# 12      NaN    NaN     NaN    NaN    NaN
# 13      NaN    NaN     NaN    NaN    NaN
# 14      NaN    NaN     NaN    NaN    NaN
# 15      NaN    NaN     NaN    NaN    NaN
# 16      NaN    NaN     NaN    NaN    NaN
# 17      NaN    NaN     NaN    NaN    NaN
# 18      NaN    NaN     NaN    NaN    NaN
# 19      NaN    NaN     NaN    NaN    NaN
# 20      NaN    NaN     NaN    NaN    NaN
# 21      NaN    NaN     NaN    NaN    NaN
# 22      NaN    NaN     NaN    NaN    NaN
# 23      NaN    NaN     NaN    NaN    NaN
# 24      NaN    NaN     NaN    NaN    NaN
# 25      NaN    NaN     NaN    NaN    NaN
# 26      NaN    NaN     NaN    NaN    NaN
# 27      NaN    NaN     NaN    NaN    NaN
# 28      NaN    NaN     NaN    NaN    NaN
# 29      NaN    NaN     NaN    NaN    NaN
# ...     ...    ...     ...    ...    ...
# 14370   NaN    NaN     NaN    NaN    NaN
# 14371   NaN    NaN     NaN    NaN    NaN
# 14372   NaN    NaN     NaN    NaN    NaN
# 14373   NaN    NaN     NaN    NaN    NaN
# 14374   NaN    NaN     NaN    NaN    NaN
# 14375   NaN    NaN     NaN    NaN    NaN
# 14376   NaN    NaN     NaN    NaN    NaN
# 14377   NaN    NaN     NaN    NaN    NaN
# 14378   NaN    NaN     NaN    NaN    NaN
# 14379   NaN    NaN     NaN    NaN    NaN
# 14380   NaN    NaN     NaN    NaN    NaN
# 14381   NaN    NaN     NaN    NaN    NaN
# 14382   NaN    NaN     NaN    NaN    NaN
# 14383   NaN    NaN     NaN    NaN    NaN
# 14384   NaN    NaN     NaN    NaN    NaN
# 14385   NaN    NaN     NaN    NaN    NaN
# 14386   NaN    NaN     NaN    NaN    NaN
# 14387   NaN    NaN     NaN    NaN    NaN
# 14388   NaN    NaN     NaN    NaN    NaN
# 14389   NaN    NaN     NaN    NaN    NaN
# 14390   NaN    NaN     NaN    NaN    NaN
# 14391   NaN    NaN     NaN    NaN    NaN
# 14392   NaN    NaN     NaN    NaN    NaN
# 14393   NaN    NaN     NaN    NaN    NaN
# 14394   NaN    NaN     NaN    NaN    NaN
# 14395   NaN    NaN     NaN    NaN    NaN
# 14396   NaN    NaN     NaN    NaN    NaN
# 14397   NaN    NaN     NaN    NaN    NaN
# 14398   NaN    NaN     NaN    NaN    NaN
# 14399   NaN    NaN     NaN    NaN    NaN
#
# [14400 rows x 14 columns]

# %%
# fill the missing data using NN (k=1)
from fancyimpute import BiScaler, KNN, NuclearNormMinimization, SoftImpute

# the reason why "day" and "minute" need to be removed before imputation is that the imputation is done based on features.
# in other words, the day and minute will have impacts on the imputed results
# to maintain a continuity of a user between days it is necessary to remove "day" and "minute" before imputation and add them back later
# also no need to imputate tower id
mobiledata_fs_test = mobiledata_fs.drop(labels = ["day"], axis=1)
mobiledata_fs_test = mobiledata_fs_test.drop(labels = ["minute"], axis=1)
mobiledata_fs_test = mobiledata_fs_test.drop(labels = ["tid"], axis=1)
mobiledata_fs_filled = KNN(k=1).complete(mobiledata_fs_test)
mobiledata_fs_filled = pd.DataFrame(mobiledata_fs_filled, columns = ["acc_time", "pid", "zone", 
                                                                     "status", "xcor", "ycor", "tpid", "tzone", 
                                                                     "radius", "txcor", "tycor"])
# Out:
# Using Theano backend.
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\tensor\signal\downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")
# Computing pairwise distances between 14400 samples
# Computing distances for sample #1/14400, elapsed time: 4.591
# Computing distances for sample #101/14400, elapsed time: 4.791
# Computing distances for sample #201/14400, elapsed time: 4.976
# Computing distances for sample #301/14400, elapsed time: 5.138
# Computing distances for sample #401/14400, elapsed time: 5.307
# Computing distances for sample #501/14400, elapsed time: 5.491
# Computing distances for sample #601/14400, elapsed time: 5.707
# Computing distances for sample #701/14400, elapsed time: 5.876
# Computing distances for sample #801/14400, elapsed time: 6.076
# Computing distances for sample #901/14400, elapsed time: 6.239
# Computing distances for sample #1001/14400, elapsed time: 6.408
# Computing distances for sample #1101/14400, elapsed time: 6.607
# Computing distances for sample #1201/14400, elapsed time: 6.793
# Computing distances for sample #1301/14400, elapsed time: 6.993
# Computing distances for sample #1401/14400, elapsed time: 7.171
# Computing distances for sample #1501/14400, elapsed time: 7.325
# Computing distances for sample #1601/14400, elapsed time: 7.493
# Computing distances for sample #1701/14400, elapsed time: 7.717
# Computing distances for sample #1801/14400, elapsed time: 7.963
# Computing distances for sample #1901/14400, elapsed time: 8.156
# Computing distances for sample #2001/14400, elapsed time: 8.393
# Computing distances for sample #2101/14400, elapsed time: 8.578
# Computing distances for sample #2201/14400, elapsed time: 8.741
# Computing distances for sample #2301/14400, elapsed time: 8.926
# Computing distances for sample #2401/14400, elapsed time: 9.142
# Computing distances for sample #2501/14400, elapsed time: 9.396
# Computing distances for sample #2601/14400, elapsed time: 9.647
# Computing distances for sample #2701/14400, elapsed time: 9.910
# Computing distances for sample #2801/14400, elapsed time: 10.128
# Computing distances for sample #2901/14400, elapsed time: 10.358
# Computing distances for sample #3001/14400, elapsed time: 10.584
# Computing distances for sample #3101/14400, elapsed time: 10.784
# Computing distances for sample #3201/14400, elapsed time: 11.000
# Computing distances for sample #3301/14400, elapsed time: 11.200
# Computing distances for sample #3401/14400, elapsed time: 11.449
# Computing distances for sample #3501/14400, elapsed time: 11.654
# Computing distances for sample #3601/14400, elapsed time: 11.918
# Computing distances for sample #3701/14400, elapsed time: 12.165
# Computing distances for sample #3801/14400, elapsed time: 12.404
# Computing distances for sample #3901/14400, elapsed time: 12.625
# Computing distances for sample #4001/14400, elapsed time: 12.833
# Computing distances for sample #4101/14400, elapsed time: 13.051
# Computing distances for sample #4201/14400, elapsed time: 13.233
# Computing distances for sample #4301/14400, elapsed time: 13.418
# Computing distances for sample #4401/14400, elapsed time: 13.602
# Computing distances for sample #4501/14400, elapsed time: 13.781
# Computing distances for sample #4601/14400, elapsed time: 13.950
# Computing distances for sample #4701/14400, elapsed time: 14.119
# Computing distances for sample #4801/14400, elapsed time: 14.334
# Computing distances for sample #4901/14400, elapsed time: 14.519
# Computing distances for sample #5001/14400, elapsed time: 14.703
# Computing distances for sample #5101/14400, elapsed time: 14.888
# Computing distances for sample #5201/14400, elapsed time: 15.082
# Computing distances for sample #5301/14400, elapsed time: 15.251
# Computing distances for sample #5401/14400, elapsed time: 15.419
# Computing distances for sample #5501/14400, elapsed time: 15.621
# Computing distances for sample #5601/14400, elapsed time: 15.891
# Computing distances for sample #5701/14400, elapsed time: 16.087
# Computing distances for sample #5801/14400, elapsed time: 16.282
# Computing distances for sample #5901/14400, elapsed time: 16.466
# Computing distances for sample #6001/14400, elapsed time: 16.635
# Computing distances for sample #6101/14400, elapsed time: 16.837
# Computing distances for sample #6201/14400, elapsed time: 16.989
# Computing distances for sample #6301/14400, elapsed time: 17.151
# Computing distances for sample #6401/14400, elapsed time: 17.340
# Computing distances for sample #6501/14400, elapsed time: 17.582
# Computing distances for sample #6601/14400, elapsed time: 17.751
# Computing distances for sample #6701/14400, elapsed time: 17.936
# Computing distances for sample #6801/14400, elapsed time: 18.104
# Computing distances for sample #6901/14400, elapsed time: 18.284
# Computing distances for sample #7001/14400, elapsed time: 18.459
# Computing distances for sample #7101/14400, elapsed time: 18.636
# Computing distances for sample #7201/14400, elapsed time: 18.824
# Computing distances for sample #7301/14400, elapsed time: 18.990
# Computing distances for sample #7401/14400, elapsed time: 19.152
# Computing distances for sample #7501/14400, elapsed time: 19.356
# Computing distances for sample #7601/14400, elapsed time: 19.522
# Computing distances for sample #7701/14400, elapsed time: 19.691
# Computing distances for sample #7801/14400, elapsed time: 19.870
# Computing distances for sample #7901/14400, elapsed time: 20.038
# Computing distances for sample #8001/14400, elapsed time: 20.207
# Computing distances for sample #8101/14400, elapsed time: 20.370
# Computing distances for sample #8201/14400, elapsed time: 20.523
# Computing distances for sample #8301/14400, elapsed time: 20.687
# Computing distances for sample #8401/14400, elapsed time: 20.870
# Computing distances for sample #8501/14400, elapsed time: 21.055
# Computing distances for sample #8601/14400, elapsed time: 21.255
# Computing distances for sample #8701/14400, elapsed time: 21.424
# Computing distances for sample #8801/14400, elapsed time: 21.624
# Computing distances for sample #8901/14400, elapsed time: 21.860
# Computing distances for sample #9001/14400, elapsed time: 22.040
# Computing distances for sample #9101/14400, elapsed time: 22.209
# Computing distances for sample #9201/14400, elapsed time: 22.394
# Computing distances for sample #9301/14400, elapsed time: 22.572
# Computing distances for sample #9401/14400, elapsed time: 22.746
# Computing distances for sample #9501/14400, elapsed time: 22.910
# Computing distances for sample #9601/14400, elapsed time: 23.073
# Computing distances for sample #9701/14400, elapsed time: 23.257
# Computing distances for sample #9801/14400, elapsed time: 23.410
# Computing distances for sample #9901/14400, elapsed time: 23.595
# Computing distances for sample #10001/14400, elapsed time: 23.773
# Computing distances for sample #10101/14400, elapsed time: 23.958
# Computing distances for sample #10201/14400, elapsed time: 24.111
# Computing distances for sample #10301/14400, elapsed time: 24.312
# Computing distances for sample #10401/14400, elapsed time: 24.572
# Computing distances for sample #10501/14400, elapsed time: 24.784
# Computing distances for sample #10601/14400, elapsed time: 24.998
# Computing distances for sample #10701/14400, elapsed time: 25.236
# Computing distances for sample #10801/14400, elapsed time: 25.412
# Computing distances for sample #10901/14400, elapsed time: 25.597
# Computing distances for sample #11001/14400, elapsed time: 25.839
# Computing distances for sample #11101/14400, elapsed time: 26.048
# Computing distances for sample #11201/14400, elapsed time: 26.217
# Computing distances for sample #11301/14400, elapsed time: 26.414
# Computing distances for sample #11401/14400, elapsed time: 26.692
# Computing distances for sample #11501/14400, elapsed time: 26.918
# Computing distances for sample #11601/14400, elapsed time: 27.116
# Computing distances for sample #11701/14400, elapsed time: 27.301
# Computing distances for sample #11801/14400, elapsed time: 27.470
# Computing distances for sample #11901/14400, elapsed time: 27.617
# Computing distances for sample #12001/14400, elapsed time: 27.817
# Computing distances for sample #12101/14400, elapsed time: 28.006
# Computing distances for sample #12201/14400, elapsed time: 28.257
# Computing distances for sample #12301/14400, elapsed time: 28.454
# Computing distances for sample #12401/14400, elapsed time: 28.638
# Computing distances for sample #12501/14400, elapsed time: 28.911
# Computing distances for sample #12601/14400, elapsed time: 29.086
# Computing distances for sample #12701/14400, elapsed time: 29.280
# Computing distances for sample #12801/14400, elapsed time: 29.520
# Computing distances for sample #12901/14400, elapsed time: 29.729
# Computing distances for sample #13001/14400, elapsed time: 29.958
# Computing distances for sample #13101/14400, elapsed time: 30.284
# Computing distances for sample #13201/14400, elapsed time: 30.477
# Computing distances for sample #13301/14400, elapsed time: 30.677
# Computing distances for sample #13401/14400, elapsed time: 30.846
# Computing distances for sample #13501/14400, elapsed time: 30.993
# Computing distances for sample #13601/14400, elapsed time: 31.146
# Computing distances for sample #13701/14400, elapsed time: 31.293
# Computing distances for sample #13801/14400, elapsed time: 31.462
# Computing distances for sample #13901/14400, elapsed time: 31.625
# Computing distances for sample #14001/14400, elapsed time: 31.827
# Computing distances for sample #14101/14400, elapsed time: 31.993
# Computing distances for sample #14201/14400, elapsed time: 32.209
# Computing distances for sample #14301/14400, elapsed time: 32.372
# Imputing row 1/14400 with 5 missing columns, elapsed time: 41.948
# Imputing row 101/14400 with 5 missing columns, elapsed time: 41.982
# Imputing row 201/14400 with 5 missing columns, elapsed time: 41.998
# Imputing row 301/14400 with 5 missing columns, elapsed time: 42.029
# Imputing row 401/14400 with 5 missing columns, elapsed time: 42.058
# Imputing row 501/14400 with 5 missing columns, elapsed time: 42.088
# Imputing row 601/14400 with 5 missing columns, elapsed time: 42.121
# Imputing row 701/14400 with 5 missing columns, elapsed time: 42.156
# Imputing row 801/14400 with 5 missing columns, elapsed time: 42.190
# Imputing row 901/14400 with 5 missing columns, elapsed time: 42.222
# Imputing row 1001/14400 with 5 missing columns, elapsed time: 42.258
# Imputing row 1101/14400 with 5 missing columns, elapsed time: 42.289
# Imputing row 1201/14400 with 5 missing columns, elapsed time: 42.326
# Imputing row 1301/14400 with 5 missing columns, elapsed time: 42.357
# Imputing row 1401/14400 with 5 missing columns, elapsed time: 42.395
# Imputing row 1501/14400 with 5 missing columns, elapsed time: 42.430
# Imputing row 1601/14400 with 5 missing columns, elapsed time: 42.468
# Imputing row 1701/14400 with 5 missing columns, elapsed time: 42.492
# Imputing row 1801/14400 with 5 missing columns, elapsed time: 42.518
# Imputing row 1901/14400 with 5 missing columns, elapsed time: 42.542
# Imputing row 2001/14400 with 5 missing columns, elapsed time: 42.565
# Imputing row 2101/14400 with 5 missing columns, elapsed time: 42.597
# Imputing row 2201/14400 with 5 missing columns, elapsed time: 42.621
# Imputing row 2301/14400 with 5 missing columns, elapsed time: 42.648
# Imputing row 2401/14400 with 5 missing columns, elapsed time: 42.672
# Imputing row 2501/14400 with 5 missing columns, elapsed time: 42.701
# Imputing row 2601/14400 with 5 missing columns, elapsed time: 42.723
# Imputing row 2701/14400 with 5 missing columns, elapsed time: 42.752
# Imputing row 2801/14400 with 5 missing columns, elapsed time: 42.776
# Imputing row 2901/14400 with 5 missing columns, elapsed time: 42.810
# Imputing row 3001/14400 with 5 missing columns, elapsed time: 42.838
# Imputing row 3101/14400 with 5 missing columns, elapsed time: 42.874
# Imputing row 3201/14400 with 5 missing columns, elapsed time: 42.912
# Imputing row 3301/14400 with 5 missing columns, elapsed time: 42.945
# Imputing row 3401/14400 with 5 missing columns, elapsed time: 42.979
# Imputing row 3501/14400 with 5 missing columns, elapsed time: 43.011
# Imputing row 3601/14400 with 5 missing columns, elapsed time: 43.034
# Imputing row 3701/14400 with 5 missing columns, elapsed time: 43.059
# Imputing row 3801/14400 with 5 missing columns, elapsed time: 43.082
# Imputing row 3901/14400 with 5 missing columns, elapsed time: 43.106
# Imputing row 4001/14400 with 5 missing columns, elapsed time: 43.133
# Imputing row 4101/14400 with 5 missing columns, elapsed time: 43.157
# Imputing row 4201/14400 with 5 missing columns, elapsed time: 43.180
# Imputing row 4301/14400 with 5 missing columns, elapsed time: 43.203
# Imputing row 4401/14400 with 5 missing columns, elapsed time: 43.224
# Imputing row 4501/14400 with 5 missing columns, elapsed time: 43.252
# Imputing row 4601/14400 with 5 missing columns, elapsed time: 43.266
# Imputing row 4701/14400 with 5 missing columns, elapsed time: 43.282
# Imputing row 4801/14400 with 5 missing columns, elapsed time: 43.328
# Imputing row 4901/14400 with 5 missing columns, elapsed time: 43.344
# Imputing row 5001/14400 with 5 missing columns, elapsed time: 43.383
# Imputing row 5101/14400 with 5 missing columns, elapsed time: 43.404
# Imputing row 5201/14400 with 5 missing columns, elapsed time: 43.433
# Imputing row 5301/14400 with 5 missing columns, elapsed time: 43.457
# Imputing row 5401/14400 with 5 missing columns, elapsed time: 43.482
# Imputing row 5501/14400 with 5 missing columns, elapsed time: 43.512
# Imputing row 5601/14400 with 5 missing columns, elapsed time: 43.546
# Imputing row 5701/14400 with 5 missing columns, elapsed time: 43.583
# Imputing row 5801/14400 with 5 missing columns, elapsed time: 43.615
# Imputing row 5901/14400 with 5 missing columns, elapsed time: 43.648
# Imputing row 6001/14400 with 5 missing columns, elapsed time: 43.686
# Imputing row 6101/14400 with 5 missing columns, elapsed time: 43.716
# Imputing row 6201/14400 with 5 missing columns, elapsed time: 43.755
# Imputing row 6301/14400 with 5 missing columns, elapsed time: 43.778
# Imputing row 6401/14400 with 5 missing columns, elapsed time: 43.806
# Imputing row 6501/14400 with 5 missing columns, elapsed time: 43.830
# Imputing row 6601/14400 with 5 missing columns, elapsed time: 43.860
# Imputing row 6701/14400 with 5 missing columns, elapsed time: 43.885
# Imputing row 6801/14400 with 5 missing columns, elapsed time: 43.913
# Imputing row 6901/14400 with 5 missing columns, elapsed time: 43.931
# Imputing row 7001/14400 with 5 missing columns, elapsed time: 43.946
# Imputing row 7101/14400 with 5 missing columns, elapsed time: 43.991
# Imputing row 7201/14400 with 5 missing columns, elapsed time: 44.016
# Imputing row 7301/14400 with 5 missing columns, elapsed time: 44.045
# Imputing row 7401/14400 with 5 missing columns, elapsed time: 44.068
# Imputing row 7501/14400 with 5 missing columns, elapsed time: 44.099
# Imputing row 7601/14400 with 5 missing columns, elapsed time: 44.122
# Imputing row 7701/14400 with 5 missing columns, elapsed time: 44.153
# Imputing row 7801/14400 with 5 missing columns, elapsed time: 44.172
# Imputing row 7901/14400 with 5 missing columns, elapsed time: 44.192
# Imputing row 8001/14400 with 5 missing columns, elapsed time: 44.229
# Imputing row 8101/14400 with 5 missing columns, elapsed time: 44.257
# Imputing row 8201/14400 with 5 missing columns, elapsed time: 44.293
# Imputing row 8301/14400 with 5 missing columns, elapsed time: 44.337
# Imputing row 8401/14400 with 5 missing columns, elapsed time: 44.380
# Imputing row 8501/14400 with 5 missing columns, elapsed time: 44.420
# Imputing row 8601/14400 with 5 missing columns, elapsed time: 44.460
# Imputing row 8701/14400 with 5 missing columns, elapsed time: 44.499
# Imputing row 8801/14400 with 5 missing columns, elapsed time: 44.541
# Imputing row 8901/14400 with 5 missing columns, elapsed time: 44.573
# Imputing row 9001/14400 with 5 missing columns, elapsed time: 44.603
# Imputing row 9101/14400 with 5 missing columns, elapsed time: 44.628
# Imputing row 9201/14400 with 5 missing columns, elapsed time: 44.656
# Imputing row 9301/14400 with 5 missing columns, elapsed time: 44.680
# Imputing row 9401/14400 with 5 missing columns, elapsed time: 44.705
# Imputing row 9501/14400 with 5 missing columns, elapsed time: 44.728
# Imputing row 9601/14400 with 5 missing columns, elapsed time: 44.735
# Imputing row 9701/14400 with 5 missing columns, elapsed time: 44.775
# Imputing row 9801/14400 with 5 missing columns, elapsed time: 44.795
# Imputing row 9901/14400 with 5 missing columns, elapsed time: 44.810
# Imputing row 10001/14400 with 5 missing columns, elapsed time: 44.845
# Imputing row 10101/14400 with 5 missing columns, elapsed time: 44.869
# Imputing row 10201/14400 with 5 missing columns, elapsed time: 44.899
# Imputing row 10301/14400 with 5 missing columns, elapsed time: 44.922
# Imputing row 10401/14400 with 5 missing columns, elapsed time: 44.948
# Imputing row 10501/14400 with 5 missing columns, elapsed time: 44.976
# Imputing row 10601/14400 with 5 missing columns, elapsed time: 45.011
# Imputing row 10701/14400 with 5 missing columns, elapsed time: 45.045
# Imputing row 10801/14400 with 5 missing columns, elapsed time: 45.082
# Imputing row 10901/14400 with 5 missing columns, elapsed time: 45.119
# Imputing row 11001/14400 with 5 missing columns, elapsed time: 45.158
# Imputing row 11101/14400 with 5 missing columns, elapsed time: 45.191
# Imputing row 11201/14400 with 5 missing columns, elapsed time: 45.228
# Imputing row 11301/14400 with 5 missing columns, elapsed time: 45.264
# Imputing row 11401/14400 with 5 missing columns, elapsed time: 45.295
# Imputing row 11501/14400 with 5 missing columns, elapsed time: 45.332
# Imputing row 11601/14400 with 5 missing columns, elapsed time: 45.367
# Imputing row 11701/14400 with 5 missing columns, elapsed time: 45.402
# Imputing row 11801/14400 with 5 missing columns, elapsed time: 45.433
# Imputing row 11901/14400 with 5 missing columns, elapsed time: 45.457
# Imputing row 12001/14400 with 5 missing columns, elapsed time: 45.485
# Imputing row 12101/14400 with 5 missing columns, elapsed time: 45.508
# Imputing row 12201/14400 with 5 missing columns, elapsed time: 45.532
# Imputing row 12301/14400 with 5 missing columns, elapsed time: 45.554
# Imputing row 12401/14400 with 5 missing columns, elapsed time: 45.578
# Imputing row 12501/14400 with 5 missing columns, elapsed time: 45.606
# Imputing row 12601/14400 with 5 missing columns, elapsed time: 45.628
# Imputing row 12701/14400 with 5 missing columns, elapsed time: 45.641
# Imputing row 12801/14400 with 5 missing columns, elapsed time: 45.675
# Imputing row 12901/14400 with 5 missing columns, elapsed time: 45.698
# Imputing row 13001/14400 with 5 missing columns, elapsed time: 45.723
# Imputing row 13101/14400 with 5 missing columns, elapsed time: 45.741
# Imputing row 13201/14400 with 5 missing columns, elapsed time: 45.768
# Imputing row 13301/14400 with 5 missing columns, elapsed time: 45.796
# Imputing row 13401/14400 with 5 missing columns, elapsed time: 45.819
# Imputing row 13501/14400 with 5 missing columns, elapsed time: 45.846
# Imputing row 13601/14400 with 5 missing columns, elapsed time: 45.877
# Imputing row 13701/14400 with 5 missing columns, elapsed time: 45.910
# Imputing row 13801/14400 with 5 missing columns, elapsed time: 45.948
# Imputing row 13901/14400 with 5 missing columns, elapsed time: 45.978
# Imputing row 14001/14400 with 5 missing columns, elapsed time: 46.012
# Imputing row 14101/14400 with 5 missing columns, elapsed time: 46.047
# Imputing row 14201/14400 with 5 missing columns, elapsed time: 46.082
# Imputing row 14301/14400 with 5 missing columns, elapsed time: 46.114

# %%
#check if imputation works as should
# add the day and minute information back
mobiledata_daymin = mobiledata_fs.ix[:,[0, 1, 2, 3, 8]]
mobiledata_fs_filled = pd.merge(mobiledata_daymin, mobiledata_fs_filled, how = 'left', on = ["acc_time", "pid"])
mobiledata_cp = pd.merge(mobiledata_fs, mobiledata_fs_filled, how = 'left', on = ["acc_time", 'day', 'minute', "pid"])


mobiledata_fs_filled.fillna(-1, inplace=True)
print mobiledata_fs_filled.count()
# Out:
# acc_time    14400
# day         14400
# minute      14400
# pid         14400
# tid         14400
# zone        14400
# status      14400
# xcor        14400
# ycor        14400
# tpid        14400
# tzone       14400
# radius      14400
# txcor       14400
# tycor       14400
# dtype: int64

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
mobiledata_sel = mobiledata_cp[mobiledata_cp['day'] == 6]
ax1.scatter(mobiledata_sel['minute'], mobiledata_sel['tzone_x'])
ax1.set_xticks(range(0, 1440, 200))
ax1.set_yticks(range(0, 45, 15))
ax2.plot(mobiledata_sel['minute'], mobiledata_sel['tzone_y'])
ax2.set_xticks(range(0, 1440, 200))
ax2.set_yticks(range(0, 45, 15))
# Out:
# [<matplotlib.axis.YTick at 0x26a11390>,
#  <matplotlib.axis.YTick at 0x26622cf8>,
#  <matplotlib.axis.YTick at 0x2697d550>]

# %%
# checking the distribution of mobile phone calls
fig2 = plt.figure(figsize=(10,5))
ax = fig2.add_subplot(1, 1, 1)
#ax.plot(mobiledata_fs['minute'][pd.notnull(mobiledata_fs['tzone'])], 'k.')
#ax.plot(pd.notnull(mobiledata_fs['tzone']), 'k.')
#ax.set_yticks([0, 1, 2])
(mobiledata_fs['minute'][pd.notnull(mobiledata_fs['tzone'])]).hist(bins=12)
#plt.hist(mobiledata_fs['minute'][pd.notnull(mobiledata_fs['tzone'])], bins=50)

# %%
# prepare for ML

X = mobiledata_fs_filled.drop('tzone', axis=1)
y = mobiledata_fs_filled['tzone']

trainX, testX, trainY, testY = train_test_split(X, y)

# %%
## using KNN
# weights might need to be changed - more weights towards the recent data?
# metrics? canberra, minkowski


clf_knn = KNeighborsClassifier(n_neighbors=1).fit(trainX, trainY)
pred_knn = clf_knn.predict(testX)
#print roc_auc_score(testY, pred_knn)
print precision_score(testY, pred_knn, average='micro')  
print recall_score(testY, pred_knn, average='micro')
# Out:
# 1.0
# 1.0

# %%
## using Ridge

clf_rdg = RidgeClassifier(alpha=1).fit(trainX,trainY)
pred_rdg = clf_rdg.predict(testX)
print precision_score(testY, pred_rdg, average='micro')  
print recall_score(testY, pred_rdg, average='micro')
# Out:
# 0.978611111111
# 0.978611111111

# %%
## using Lasso

clf_las = Lasso(alpha=1).fit(trainX,trainY)
pred_las = clf_las.predict(testX)
print precision_score(testY, pred_las, average='micro')  
print recall_score(testY, pred_las, average='micro')

# %%
## using RF

clf_rf = RandomForestClassifier(n_estimators=100, max_depth=10)
clf_rf.fit(trainX, trainY)
pred_rf = clf_rf.predict(testX)
print precision_score(testY, pred_rf, average='micro')  
print recall_score(testY, pred_rf, average='micro')
# Out:
# 1.0
# 1.0

# %%
## using GBDT

clf_gb = GradientBoostingClassifier(n_estimators=100, max_depth=3)
clf_gb.fit(trainX, trainY)
pred_gb = clf_gb.predict(testX)
print precision_score(testY, pred_gb, average='micro')  
print recall_score(testY, pred_gb, average='micro')
# Out:
# 1.0
# 1.0

# %%
# neural network
def fit_predict_NN(trainX, trainY, testX, activate_functions, hidden_layers):
    X_ = theano.shared(trainX, name='X')
    y_ = theano.shared(trainY, name='y')
    param = T.vector()
    dim = X.shape[1]
    
    def activation(data_, parameter):
        n_previous = 0
        dim_previous = dim
        h = data_
        for n_hidden, func in zip(hidden_layers, activate_functions):
            N = dim_previous * n_hidden
            W_ = parameter[n_previous:n_previous + N].reshape((dim_previous, n_hidden))
            h = func(h.dot(W_))
            dim_previous = n_hidden
            n_previous += N

        # output     
        v_ = parameter[n_previous:]
        output = h.dot(v_)
        n_previous = n_previous + dim_previous
        
        return T.nnet.sigmoid(output), n_previous

    p_sig = activation(X_, param)[0]
    p_bck = 1 - p_sig
    llh_ = y_.dot(T.log(p_sig)) + (1 - y_).dot(T.log(p_bck))
    loss = -llh_
    
    # optimize
    loss_function = theano.function([param], loss)
    loss_grad = theano.function([param], theano.grad(loss, param))
    result = minimize(loss_function, jac=loss_grad, x0=numpy.random.normal(size=activation(X_, param)[1]))
    optimal_params = result['x']
    
    # predict data
    data = T.matrix()
    compiled_activation = theano.function([data, param], activation(data, param)[0])
    
    return compiled_activation(testX, optimal_params)

# %%
## define activation function
#sigmoid (which we used, T.nnet.sigmoid)
#leaky ReLU (defined below)
#softplus (T.nnet.softplus)

def LeakyReLU(x):
    return T.switch(x > 0, x, 0.5 * x)

# %%
pred = fit_predict_NN(trainX, trainY, testX, [T.nnet.sigmoid] * 3, [20, 10, 5])
print precision_score(testY, pred, average='micro')  
print recall_score(testY, pred, average='micro')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-2dff3e1fc82a> in <module>()
# ----> 1 pred = fit_predict_NN(trainX, trainY, testX, [T.nnet.sigmoid] * 3, [20, 10, 5])
#       2 print precision_score(testY, pred_gb, average='micro')
#       3 print recall_score(testY, pred_gb, average='micro')
#
# <ipython-input-20-3d2c600e86ba> in fit_predict_NN(trainX, trainY, testX, activate_functions, hidden_layers)
#      24         return T.nnet.sigmoid(output), n_previous
#      25
# ---> 26     p_sig = activation(X_, param)[0]
#      27     p_bck = 1 - p_sig
#      28     llh_ = y_.dot(T.log(p_sig)) + (1 - y_).dot(T.log(p_bck))
#
# <ipython-input-20-3d2c600e86ba> in activation(data_, parameter)
#      13             N = dim_previous * n_hidden
#      14             W_ = parameter[n_previous:n_previous + N].reshape((dim_previous, n_hidden))
# ---> 15             h = func(h.dot(W_))
#      16             dim_previous = n_hidden
#      17             n_previous += N
#
# AttributeError: 'SharedVariable' object has no attribute 'dot'
