# %%
# import functions
import pandas as pd
import numpy as np
import codecs
import matplotlib.pyplot as plt

from fancyimpute import BiScaler, KNN, NuclearNormMinimization, SoftImpute
from sklearn.preprocessing import StandardScaler                 #normalising features
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.pipeline import make_pipeline
from sklearn.cross_validation import KFold

from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import Lasso
from sklearn.svm import SVC, SVR

from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sknn import mlp

from scipy.optimize import minimize

import theano
import theano.tensor as T

# %matplotlib inline

np.random.seed=10
# Out:
# Using Theano backend.
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\tensor\signal\downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
import matplotlib.pyplot as plt

from py4j.java_gateway import JavaGateway

# %%
# %matplotlib inline

# %% [markdown]
# # set up connection

# %%
gw = JavaGateway() # New gateway connection
bridge = gw.entry_point

# %% [markdown]
# # load netlogo model

# %%
# Path to the model:
models_path = "D:/Work/PhD/Github/NetLogoModel/"
model_name = "PhD_InitialModelV2.nlogo"

# %%
modelLocation = models_path + model_name

# %%
bridge.openModel(modelLocation)

# %% [markdown]
# # Run one iteration of the model, one command at a time:

# %%
bridge.command("set grid-size 21")
bridge.command("set nb-people 1")
bridge.command("set Show_Names_Nodes? False")
bridge.command("set Show_Names_people? False")
bridge.command("set car-speed 1")
bridge.command("set mobiletowerdata? True")
bridge.command("set socialmedia_data? True")
bridge.command("set grids_covered_vector 5")
bridge.command("set avg_num_calls_perday 1")
bridge.command("set avg_call_duration_mins 2")

bridge.command("random-seed 0")
bridge.command("setup")
bridge.command("repeat 1440 [go]")

# %%
bridge.command("repeat 1440 [go]")

# %% [markdown]
# # Have the model report results

# %%
# !head -n 15 ./agentdata.txt
# Out:
#  0 0 0 441 15 0 30 -37 453
#  1 0 1 441 15 0 30 -37 453
#  2 0 2 441 15 0 30 -37 453
#  3 0 3 441 15 0 30 -37 453
#  4 0 4 441 15 0 30 -37 453
#  5 0 5 441 15 0 30 -37 453
#  6 0 6 441 15 0 30 -37 453
#  7 0 7 441 15 0 30 -37 453
#  8 0 8 441 15 0 30 -37 453
#  9 0 9 441 15 0 30 -37 453
#  10 0 10 441 15 0 30 -37 453
#  11 0 11 441 15 0 30 -37 453
#  12 0 12 441 15 0 30 -37 453
#  13 0 13 441 15 0 30 -37 453
#  14 0 14 441 15 0 30 -37 453

# %%
# !head -n 15 ./mobiletowers.txt
# Out:
#  909 0 909 441 0 25 9.523809523809524 458 -16 16
#  983 0 983 441 0 25 9.523809523809524 470 -32 16

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %%
# import simuated data
# using function as the file can be closed automatically
def rawimport(path, columnname):
    agentdata = pd.read_csv(path, delimiter=' ', header=None, names=columnname)
    agentdata = agentdata.drop(labels="todrop", axis=1)
    return agentdata

# %%
#def run_NL():
#    bridge.command("random-seed 0")
#    bridge.command("setup")
#    bridge.command("repeat 14400 [go]")

# %%
#class ReturnValue(object):
#    def __init__(self, y0, y1):
#        self.y0 = y0
#        self.y1 = y1

def data_input():
    path = './agentdata.txt'
    columnname = ["todrop", "acc_time", "day", "minute", "pid", "zone", "status", "xcor", "ycor", "tid"]
    agentdata = rawimport(path, columnname)
    
    path = './mobiletowers.txt'
    columnname = ["todrop", "acc_time", "day", "minute", "pid", "tpid", "tzone", "radius", "tid", "txcor", "tycor"]
    mobiledata = rawimport(path, columnname)
    
    # extend data to full (missing data shown as NaN)
    mobiledata = mobiledata.drop(labels = ["tid"], axis=1)

    mobiledata_fs = pd.merge(agentdata, mobiledata, how = 'left', on = ["acc_time", 'day', 'minute', "pid"])
    #mobiledata_fs = pd.merge(agentdata_ri, mobiledata_ri, how = 'left', left_index = True, right_index = True)
    #print mobiledata_fs.count()
    #mobiledata_fs
# fill the missing data using NN (k=1)
# the reason why "day" and "minute" need to be removed before imputation is that the imputation is done based on features.
# in other words, the day and minute will have impacts on the imputed results
# to maintain a continuity of a user between days it is necessary to remove "day" and "minute" before imputation and add them back later
# also no need to imputate tower id
    mobiledata_fs_test = mobiledata_fs.drop(labels = ["day"], axis=1)
    mobiledata_fs_test = mobiledata_fs_test.drop(labels = ["minute"], axis=1)
    mobiledata_fs_test = mobiledata_fs_test.drop(labels = ["tid"], axis=1)
    mobiledata_fs_filled = KNN(k=1).complete(mobiledata_fs_test)
    mobiledata_fs_filled = pd.DataFrame(mobiledata_fs_filled, columns = ["acc_time", "pid", "zone", 
                                                                     "status", "xcor", "ycor", "tpid", "tzone", 
                                                                     "radius", "txcor", "tycor"])
# add the day and minute information back
    mobiledata_daymin = mobiledata_fs.ix[:,[0, 1, 2, 3, 8]]
    mobiledata_fs_filled = pd.merge(mobiledata_daymin, mobiledata_fs_filled, how = 'left', on = ["acc_time", "pid"])
    mobiledata_cp = pd.merge(mobiledata_fs, mobiledata_fs_filled, how = 'left', on = ["acc_time", 'day', 'minute', "pid"])
    mobiledata_fs_filled.fillna(-1, inplace=True)
    
    return (mobiledata_fs, mobiledata_fs_filled, mobiledata_cp)

# %%
#run_NL()

mobiledata_fs, mobiledata_fs_filled, mobiledata_cp = data_input()
#miss_imput()
# Out:
# Computing pairwise distances between 1440 samples
# Computing distances for sample #1/1440, elapsed time: 0.048
# Computing distances for sample #101/1440, elapsed time: 0.065
# Computing distances for sample #201/1440, elapsed time: 0.087
# Computing distances for sample #301/1440, elapsed time: 0.104
# Computing distances for sample #401/1440, elapsed time: 0.117
# Computing distances for sample #501/1440, elapsed time: 0.142
# Computing distances for sample #601/1440, elapsed time: 0.160
# Computing distances for sample #701/1440, elapsed time: 0.178
# Computing distances for sample #801/1440, elapsed time: 0.204
# Computing distances for sample #901/1440, elapsed time: 0.222
# Computing distances for sample #1001/1440, elapsed time: 0.239
# Computing distances for sample #1101/1440, elapsed time: 0.261
# Computing distances for sample #1201/1440, elapsed time: 0.278
# Computing distances for sample #1301/1440, elapsed time: 0.295
# Computing distances for sample #1401/1440, elapsed time: 0.314
# Imputing row 1/1440 with 5 missing columns, elapsed time: 0.387
# Imputing row 101/1440 with 5 missing columns, elapsed time: 0.410
# Imputing row 201/1440 with 5 missing columns, elapsed time: 0.423
# Imputing row 301/1440 with 5 missing columns, elapsed time: 0.433
# Imputing row 401/1440 with 5 missing columns, elapsed time: 0.443
# Imputing row 501/1440 with 5 missing columns, elapsed time: 0.454
# Imputing row 601/1440 with 5 missing columns, elapsed time: 0.468
# Imputing row 701/1440 with 5 missing columns, elapsed time: 0.478
# Imputing row 801/1440 with 5 missing columns, elapsed time: 0.489
# Imputing row 901/1440 with 5 missing columns, elapsed time: 0.498
# Imputing row 1001/1440 with 5 missing columns, elapsed time: 0.511
# Imputing row 1101/1440 with 5 missing columns, elapsed time: 0.527
# Imputing row 1201/1440 with 5 missing columns, elapsed time: 0.537
# Imputing row 1301/1440 with 5 missing columns, elapsed time: 0.548
# Imputing row 1401/1440 with 5 missing columns, elapsed time: 0.558

# %%
print mobiledata_fs_filled.count()
# Out:
# acc_time    1440
# day         1440
# minute      1440
# pid         1440
# tid         1440
# zone        1440
# status      1440
# xcor        1440
# ycor        1440
# tpid        1440
# tzone       1440
# radius      1440
# txcor       1440
# tycor       1440
# dtype: int64

# %%
mobiledata_fs_filled.zone.max()
# Out:
# 45.0

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
mobiledata_sel = mobiledata_cp[mobiledata_cp['day'] == 0]
ax1.scatter(mobiledata_sel['minute'], mobiledata_sel['tzone_x'])
ax1.set_xticks(range(0, 1440, 200))
ax1.set_yticks(range(0, 45, 15))
ax2.plot(mobiledata_sel['minute'], mobiledata_sel['tzone_y'])
ax2.set_xticks(range(0, 1440, 200))
ax2.set_yticks(range(0, 45, 15))
# Out:
# [<matplotlib.axis.YTick at 0x31fb3278>,
#  <matplotlib.axis.YTick at 0x31fb34e0>,
#  <matplotlib.axis.YTick at 0x30bcf438>]

# %%
# checking the distribution of mobile phone calls
fig2 = plt.figure(figsize=(10,5))
ax = fig2.add_subplot(1, 1, 1)
#ax.plot(mobiledata_fs['minute'][pd.notnull(mobiledata_fs['tzone'])], 'k.')
#ax.plot(pd.notnull(mobiledata_fs['tzone']), 'k.')
#ax.set_yticks([0, 1, 2])
(mobiledata_fs['minute'][pd.notnull(mobiledata_fs['tzone'])]).hist(bins=12)
#plt.hist(mobiledata_fs['minute'][pd.notnull(mobiledata_fs['tzone'])], bins=50)

# %%
# ML
def NL_ML(mobiledata_fs_filled):
    # prepare for ML
    X = mobiledata_fs_filled.drop('zone', axis=1)
    y = mobiledata_fs_filled['zone']
    trainX, testX, trainY, testY = train_test_split(X, y)
    
    ## using KNN
    # weights might need to be changed - more weights towards the recent data?
    # metrics? canberra, minkowski
    clf_knn = KNeighborsClassifier(n_neighbors=1).fit(trainX, trainY)
    pred_knn = clf_knn.predict(testX)
    #print roc_auc_score(testY, pred_knn)
    knn_PR = precision_score(testY, pred_knn, average='micro')
    knn_CM = confusion_matrix(testY, pred_knn)
    
    ## using ridge regression
    clf_rdg = RidgeClassifier(alpha=1).fit(trainX,trainY)
    pred_rdg = clf_rdg.predict(testX)
    rdg_PR = precision_score(testY, pred_rdg, average='micro')  
    rdg_CM = confusion_matrix(testY, pred_rdg)
    
    ## using RF
    clf_rf = RandomForestClassifier(n_estimators=100, max_depth=10)
    clf_rf.fit(trainX, trainY)
    pred_rf = clf_rf.predict(testX)
    rf_PR = precision_score(testY, pred_rf, average='micro')  
    rf_CM = confusion_matrix(testY, pred_rf)
    
    ## using GBDT
    clf_gb = GradientBoostingClassifier(n_estimators=100, max_depth=3)
    clf_gb.fit(trainX, trainY)
    pred_gb = clf_gb.predict(testX)
    gb_PR = precision_score(testY, pred_gb, average='micro')  
    gb_CM = confusion_matrix(testY, pred_gb)
    
    return (knn_PR, knn_CM, rdg_PR, rdg_CM, rf_PR, rf_CM, gb_PR, gb_CM)

# %%
def run_NL(mob_call):
    bridge.command("set grid-size 21")
    bridge.command("set nb-people 1")
    bridge.command("set Show_Names_Nodes? False")
    bridge.command("set Show_Names_people? False")
    bridge.command("set car-speed 1")
    bridge.command("set mobiletowerdata? True")
    bridge.command("set socialmedia_data? True")
    bridge.command("set grids_covered_vector 5")
    bridge.command("set avg_num_calls_perday 1")
    bridge.command("set avg_call_duration_mins 2")
    bridge.command("random-seed 0")
    bridge.command("setup")
    bridge.command(mob_call)

# %%
# Out:
# array([[2247,    0,    0,    0],
#        [   0, 1088,    0,    0],
#        [   0,    0,  185,    0],
#        [   0,    0,    0,   80]])

# %%
knn_all_PR = []
rdg_all_PR = []
rf_all_PR = []
gb_all_PR = []
knn_all_CM = []
rdg_all_CM = []
rf_all_CM = []
gb_all_CM = []


for x in range(1440, 14400, 1440):
    print x
    mob_call = "repeat " + str(x) + " [go]" 
    run_NL(mob_call)
    comdata_fs, comdata_fs_filled, comdata_cp = data_input()
    t = NL_ML(comdata_fs_filled)
    knn_all_PR.append(t[0])
    rdg_all_PR.append(t[2])
    rf_all_PR.append(t[4])
    gb_all_PR.append(t[6])
    knn_all_CM.append(t[1])
    rdg_all_CM.append(t[3])
    rf_all_CM.append(t[5])
    gb_all_CM.append(t[7])
# Out:
# 1440
# Computing pairwise distances between 1440 samples
# Computing distances for sample #1/1440, elapsed time: 0.060
# Computing distances for sample #101/1440, elapsed time: 0.078
# Computing distances for sample #201/1440, elapsed time: 0.098
# Computing distances for sample #301/1440, elapsed time: 0.115
# Computing distances for sample #401/1440, elapsed time: 0.133
# Computing distances for sample #501/1440, elapsed time: 0.156
# Computing distances for sample #601/1440, elapsed time: 0.174
# Computing distances for sample #701/1440, elapsed time: 0.184
# Computing distances for sample #801/1440, elapsed time: 0.215
# Computing distances for sample #901/1440, elapsed time: 0.232
# Computing distances for sample #1001/1440, elapsed time: 0.249
# Computing distances for sample #1101/1440, elapsed time: 0.272
# Computing distances for sample #1201/1440, elapsed time: 0.291
# Computing distances for sample #1301/1440, elapsed time: 0.295
# Computing distances for sample #1401/1440, elapsed time: 0.326
# Imputing row 1/1440 with 5 missing columns, elapsed time: 0.412
# Imputing row 101/1440 with 5 missing columns, elapsed time: 0.426
# Imputing row 201/1440 with 5 missing columns, elapsed time: 0.441
# Imputing row 301/1440 with 5 missing columns, elapsed time: 0.451
# Imputing row 401/1440 with 5 missing columns, elapsed time: 0.462
# Imputing row 501/1440 with 5 missing columns, elapsed time: 0.472
# Imputing row 601/1440 with 5 missing columns, elapsed time: 0.484
# Imputing row 701/1440 with 5 missing columns, elapsed time: 0.499
# Imputing row 801/1440 with 5 missing columns, elapsed time: 0.509
# Imputing row 901/1440 with 5 missing columns, elapsed time: 0.517
# Imputing row 1001/1440 with 5 missing columns, elapsed time: 0.517
# Imputing row 1101/1440 with 5 missing columns, elapsed time: 0.533
# Imputing row 1201/1440 with 5 missing columns, elapsed time: 0.551
# Imputing row 1301/1440 with 5 missing columns, elapsed time: 0.566
# Imputing row 1401/1440 with 5 missing columns, elapsed time: 0.577
# 2880
# Computing pairwise distances between 2880 samples
# Computing distances for sample #1/2880, elapsed time: 0.201
# Computing distances for sample #101/2880, elapsed time: 0.238
# Computing distances for sample #201/2880, elapsed time: 0.263
# Computing distances for sample #301/2880, elapsed time: 0.309
# Computing distances for sample #401/2880, elapsed time: 0.328
# Computing distances for sample #501/2880, elapsed time: 0.373
# Computing distances for sample #601/2880, elapsed time: 0.404
# Computing distances for sample #701/2880, elapsed time: 0.446
# Computing distances for sample #801/2880, elapsed time: 0.468
# Computing distances for sample #901/2880, elapsed time: 0.515
# Computing distances for sample #1001/2880, elapsed time: 0.547
# Computing distances for sample #1101/2880, elapsed time: 0.581
# Computing distances for sample #1201/2880, elapsed time: 0.648
# Computing distances for sample #1301/2880, elapsed time: 0.696
# Computing distances for sample #1401/2880, elapsed time: 0.745
# Computing distances for sample #1501/2880, elapsed time: 0.802
# Computing distances for sample #1601/2880, elapsed time: 0.853
# Computing distances for sample #1701/2880, elapsed time: 0.884
# Computing distances for sample #1801/2880, elapsed time: 0.919
# Computing distances for sample #1901/2880, elapsed time: 0.949
# Computing distances for sample #2001/2880, elapsed time: 0.986
# Computing distances for sample #2101/2880, elapsed time: 1.008
# Computing distances for sample #2201/2880, elapsed time: 1.049
# Computing distances for sample #2301/2880, elapsed time: 1.080
# Computing distances for sample #2401/2880, elapsed time: 1.118
# Computing distances for sample #2501/2880, elapsed time: 1.134
# Computing distances for sample #2601/2880, elapsed time: 1.189
# Computing distances for sample #2701/2880, elapsed time: 1.225
# Computing distances for sample #2801/2880, elapsed time: 1.256
# Imputing row 1/2880 with 5 missing columns, elapsed time: 1.603
# Imputing row 101/2880 with 5 missing columns, elapsed time: 1.622
# Imputing row 201/2880 with 5 missing columns, elapsed time: 1.638
# Imputing row 301/2880 with 5 missing columns, elapsed time: 1.661
# Imputing row 401/2880 with 5 missing columns, elapsed time: 1.682
# Imputing row 501/2880 with 5 missing columns, elapsed time: 1.699
# Imputing row 601/2880 with 5 missing columns, elapsed time: 1.717
# Imputing row 701/2880 with 5 missing columns, elapsed time: 1.739
# Imputing row 801/2880 with 5 missing columns, elapsed time: 1.755
# Imputing row 901/2880 with 5 missing columns, elapsed time: 1.769
# Imputing row 1001/2880 with 5 missing columns, elapsed time: 1.788
# Imputing row 1101/2880 with 5 missing columns, elapsed time: 1.816
# Imputing row 1201/2880 with 5 missing columns, elapsed time: 1.833
# Imputing row 1301/2880 with 5 missing columns, elapsed time: 1.855
# Imputing row 1401/2880 with 5 missing columns, elapsed time: 1.872
# Imputing row 1501/2880 with 5 missing columns, elapsed time: 1.887
# Imputing row 1601/2880 with 5 missing columns, elapsed time: 1.900
# Imputing row 1701/2880 with 5 missing columns, elapsed time: 1.914
# Imputing row 1801/2880 with 5 missing columns, elapsed time: 1.926
# Imputing row 1901/2880 with 5 missing columns, elapsed time: 1.938
# Imputing row 2001/2880 with 5 missing columns, elapsed time: 1.939
# Imputing row 2101/2880 with 5 missing columns, elapsed time: 1.964
# Imputing row 2201/2880 with 5 missing columns, elapsed time: 1.978
# Imputing row 2301/2880 with 5 missing columns, elapsed time: 1.989
# Imputing row 2401/2880 with 5 missing columns, elapsed time: 2.002
# Imputing row 2501/2880 with 5 missing columns, elapsed time: 2.020
# Imputing row 2601/2880 with 5 missing columns, elapsed time: 2.032
# Imputing row 2701/2880 with 5 missing columns, elapsed time: 2.041
# Imputing row 2801/2880 with 5 missing columns, elapsed time: 2.056
# 4320
# Computing pairwise distances between 4320 samples
# Computing distances for sample #1/4320, elapsed time: 0.450
# Computing distances for sample #101/4320, elapsed time: 0.506
# Computing distances for sample #201/4320, elapsed time: 0.555
# Computing distances for sample #301/4320, elapsed time: 0.600
# Computing distances for sample #401/4320, elapsed time: 0.650
# Computing distances for sample #501/4320, elapsed time: 0.695
# Computing distances for sample #601/4320, elapsed time: 0.751
# Computing distances for sample #701/4320, elapsed time: 0.803
# Computing distances for sample #801/4320, elapsed time: 0.854
# Computing distances for sample #901/4320, elapsed time: 0.899
# Computing distances for sample #1001/4320, elapsed time: 0.951
# Computing distances for sample #1101/4320, elapsed time: 1.009
# Computing distances for sample #1201/4320, elapsed time: 1.077
# Computing distances for sample #1301/4320, elapsed time: 1.142
# Computing distances for sample #1401/4320, elapsed time: 1.210
# Computing distances for sample #1501/4320, elapsed time: 1.271
# Computing distances for sample #1601/4320, elapsed time: 1.330
# Computing distances for sample #1701/4320, elapsed time: 1.379
# Computing distances for sample #1801/4320, elapsed time: 1.416
# Computing distances for sample #1901/4320, elapsed time: 1.469
# Computing distances for sample #2001/4320, elapsed time: 1.519
# Computing distances for sample #2101/4320, elapsed time: 1.568
# Computing distances for sample #2201/4320, elapsed time: 1.635
# Computing distances for sample #2301/4320, elapsed time: 1.698
# Computing distances for sample #2401/4320, elapsed time: 1.774
# Computing distances for sample #2501/4320, elapsed time: 1.834
# Computing distances for sample #2601/4320, elapsed time: 1.887
# Computing distances for sample #2701/4320, elapsed time: 1.935
# Computing distances for sample #2801/4320, elapsed time: 1.975
# Computing distances for sample #2901/4320, elapsed time: 2.034
# Computing distances for sample #3001/4320, elapsed time: 2.080
# Computing distances for sample #3101/4320, elapsed time: 2.116
# Computing distances for sample #3201/4320, elapsed time: 2.174
# Computing distances for sample #3301/4320, elapsed time: 2.224
# Computing distances for sample #3401/4320, elapsed time: 2.275
# Computing distances for sample #3501/4320, elapsed time: 2.316
# Computing distances for sample #3601/4320, elapsed time: 2.348
# Computing distances for sample #3701/4320, elapsed time: 2.404
# Computing distances for sample #3801/4320, elapsed time: 2.449
# Computing distances for sample #3901/4320, elapsed time: 2.479
# Computing distances for sample #4001/4320, elapsed time: 2.538
# Computing distances for sample #4101/4320, elapsed time: 2.586
# Computing distances for sample #4201/4320, elapsed time: 2.619
# Computing distances for sample #4301/4320, elapsed time: 2.664
# Imputing row 1/4320 with 5 missing columns, elapsed time: 3.523
# Imputing row 101/4320 with 5 missing columns, elapsed time: 3.544
# Imputing row 201/4320 with 5 missing columns, elapsed time: 3.567
# Imputing row 301/4320 with 5 missing columns, elapsed time: 3.586
# Imputing row 401/4320 with 5 missing columns, elapsed time: 3.609
# Imputing row 501/4320 with 5 missing columns, elapsed time: 3.629
# Imputing row 601/4320 with 5 missing columns, elapsed time: 3.642
# Imputing row 701/4320 with 5 missing columns, elapsed time: 3.658
# Imputing row 801/4320 with 5 missing columns, elapsed time: 3.675
# Imputing row 901/4320 with 5 missing columns, elapsed time: 3.688
# Imputing row 1001/4320 with 5 missing columns, elapsed time: 3.701
# Imputing row 1101/4320 with 5 missing columns, elapsed time: 3.717
# Imputing row 1201/4320 with 5 missing columns, elapsed time: 3.739
# Imputing row 1301/4320 with 5 missing columns, elapsed time: 3.752
# Imputing row 1401/4320 with 5 missing columns, elapsed time: 3.756
# Imputing row 1501/4320 with 5 missing columns, elapsed time: 3.783
# Imputing row 1601/4320 with 5 missing columns, elapsed time: 3.801
# Imputing row 1701/4320 with 5 missing columns, elapsed time: 3.814
# Imputing row 1801/4320 with 5 missing columns, elapsed time: 3.836
# Imputing row 1901/4320 with 5 missing columns, elapsed time: 3.852
# Imputing row 2001/4320 with 5 missing columns, elapsed time: 3.865
# Imputing row 2101/4320 with 5 missing columns, elapsed time: 3.877
# Imputing row 2201/4320 with 5 missing columns, elapsed time: 3.898
# Imputing row 2301/4320 with 5 missing columns, elapsed time: 3.916
# Imputing row 2401/4320 with 5 missing columns, elapsed time: 3.929
# Imputing row 2501/4320 with 5 missing columns, elapsed time: 3.944
# Imputing row 2601/4320 with 5 missing columns, elapsed time: 3.960
# Imputing row 2701/4320 with 5 missing columns, elapsed time: 3.973
# Imputing row 2801/4320 with 5 missing columns, elapsed time: 3.978
# Imputing row 2901/4320 with 5 missing columns, elapsed time: 3.998
# Imputing row 3001/4320 with 5 missing columns, elapsed time: 4.013
# Imputing row 3101/4320 with 5 missing columns, elapsed time: 4.033
# Imputing row 3201/4320 with 5 missing columns, elapsed time: 4.046
# Imputing row 3301/4320 with 5 missing columns, elapsed time: 4.058
# Imputing row 3401/4320 with 5 missing columns, elapsed time: 4.081
# Imputing row 3501/4320 with 5 missing columns, elapsed time: 4.104
# Imputing row 3601/4320 with 5 missing columns, elapsed time: 4.122
# Imputing row 3701/4320 with 5 missing columns, elapsed time: 4.142
# Imputing row 3801/4320 with 5 missing columns, elapsed time: 4.160
# Imputing row 3901/4320 with 5 missing columns, elapsed time: 4.175
# Imputing row 4001/4320 with 5 missing columns, elapsed time: 4.201
# Imputing row 4101/4320 with 5 missing columns, elapsed time: 4.225
# Imputing row 4201/4320 with 5 missing columns, elapsed time: 4.242
# Imputing row 4301/4320 with 5 missing columns, elapsed time: 4.260
# 5760
# Computing pairwise distances between 5760 samples
# Computing distances for sample #1/5760, elapsed time: 0.649
# Computing distances for sample #101/5760, elapsed time: 0.702
# Computing distances for sample #201/5760, elapsed time: 0.776
# Computing distances for sample #301/5760, elapsed time: 0.837
# Computing distances for sample #401/5760, elapsed time: 0.882
# Computing distances for sample #501/5760, elapsed time: 0.958
# Computing distances for sample #601/5760, elapsed time: 1.018
# Computing distances for sample #701/5760, elapsed time: 1.078
# Computing distances for sample #801/5760, elapsed time: 1.143
# Computing distances for sample #901/5760, elapsed time: 1.204
# Computing distances for sample #1001/5760, elapsed time: 1.265
# Computing distances for sample #1101/5760, elapsed time: 1.324
# Computing distances for sample #1201/5760, elapsed time: 1.385
# Computing distances for sample #1301/5760, elapsed time: 1.461
# Computing distances for sample #1401/5760, elapsed time: 1.521
# Computing distances for sample #1501/5760, elapsed time: 1.582
# Computing distances for sample #1601/5760, elapsed time: 1.637
# Computing distances for sample #1701/5760, elapsed time: 1.707
# Computing distances for sample #1801/5760, elapsed time: 1.768
# Computing distances for sample #1901/5760, elapsed time: 1.827
# Computing distances for sample #2001/5760, elapsed time: 1.898
# Computing distances for sample #2101/5760, elapsed time: 1.948
# Computing distances for sample #2201/5760, elapsed time: 2.002
# Computing distances for sample #2301/5760, elapsed time: 2.069
# Computing distances for sample #2401/5760, elapsed time: 2.147
# Computing distances for sample #2501/5760, elapsed time: 2.210
# Computing distances for sample #2601/5760, elapsed time: 2.271
# Computing distances for sample #2701/5760, elapsed time: 2.331
# Computing distances for sample #2801/5760, elapsed time: 2.402
# Computing distances for sample #2901/5760, elapsed time: 2.452
# Computing distances for sample #3001/5760, elapsed time: 2.518
# Computing distances for sample #3101/5760, elapsed time: 2.592
# Computing distances for sample #3201/5760, elapsed time: 2.650
# Computing distances for sample #3301/5760, elapsed time: 2.714
# Computing distances for sample #3401/5760, elapsed time: 2.774
# Computing distances for sample #3501/5760, elapsed time: 2.835
# Computing distances for sample #3601/5760, elapsed time: 2.903
# Computing distances for sample #3701/5760, elapsed time: 2.956
# Computing distances for sample #3801/5760, elapsed time: 3.016
# Computing distances for sample #3901/5760, elapsed time: 3.098
# Computing distances for sample #4001/5760, elapsed time: 3.157
# Computing distances for sample #4101/5760, elapsed time: 3.217
# Computing distances for sample #4201/5760, elapsed time: 3.278
# Computing distances for sample #4301/5760, elapsed time: 3.338
# Computing distances for sample #4401/5760, elapsed time: 3.403
# Computing distances for sample #4501/5760, elapsed time: 3.459
# Computing distances for sample #4601/5760, elapsed time: 3.519
# Computing distances for sample #4701/5760, elapsed time: 3.595
# Computing distances for sample #4801/5760, elapsed time: 3.660
# Computing distances for sample #4901/5760, elapsed time: 3.721
# Computing distances for sample #5001/5760, elapsed time: 3.781
# Computing distances for sample #5101/5760, elapsed time: 3.841
# Computing distances for sample #5201/5760, elapsed time: 3.904
# Computing distances for sample #5301/5760, elapsed time: 3.962
# Computing distances for sample #5401/5760, elapsed time: 4.024
# Computing distances for sample #5501/5760, elapsed time: 4.104
# Computing distances for sample #5601/5760, elapsed time: 4.164
# Computing distances for sample #5701/5760, elapsed time: 4.225
# Imputing row 1/5760 with 5 missing columns, elapsed time: 5.522
# Imputing row 101/5760 with 5 missing columns, elapsed time: 5.553
# Imputing row 201/5760 with 5 missing columns, elapsed time: 5.569
# Imputing row 301/5760 with 5 missing columns, elapsed time: 5.583
# Imputing row 401/5760 with 5 missing columns, elapsed time: 5.602
# Imputing row 501/5760 with 5 missing columns, elapsed time: 5.617
# Imputing row 601/5760 with 5 missing columns, elapsed time: 5.632
# Imputing row 701/5760 with 5 missing columns, elapsed time: 5.634
# Imputing row 801/5760 with 5 missing columns, elapsed time: 5.663
# Imputing row 901/5760 with 5 missing columns, elapsed time: 5.681
# Imputing row 1001/5760 with 5 missing columns, elapsed time: 5.696
# Imputing row 1101/5760 with 5 missing columns, elapsed time: 5.711
# Imputing row 1201/5760 with 5 missing columns, elapsed time: 5.727
# Imputing row 1301/5760 with 5 missing columns, elapsed time: 5.742
# Imputing row 1401/5760 with 5 missing columns, elapsed time: 5.756
# Imputing row 1501/5760 with 5 missing columns, elapsed time: 5.771
# Imputing row 1601/5760 with 5 missing columns, elapsed time: 5.786
# Imputing row 1701/5760 with 5 missing columns, elapsed time: 5.802
# Imputing row 1801/5760 with 5 missing columns, elapsed time: 5.815
# Imputing row 1901/5760 with 5 missing columns, elapsed time: 5.832
# Imputing row 2001/5760 with 5 missing columns, elapsed time: 5.848
# Imputing row 2101/5760 with 5 missing columns, elapsed time: 5.864
# Imputing row 2201/5760 with 5 missing columns, elapsed time: 5.875
# Imputing row 2301/5760 with 5 missing columns, elapsed time: 5.896
# Imputing row 2401/5760 with 5 missing columns, elapsed time: 5.914
# Imputing row 2501/5760 with 5 missing columns, elapsed time: 5.928
# Imputing row 2601/5760 with 5 missing columns, elapsed time: 5.950
# Imputing row 2701/5760 with 5 missing columns, elapsed time: 5.967
# Imputing row 2801/5760 with 5 missing columns, elapsed time: 5.976
# Imputing row 2901/5760 with 5 missing columns, elapsed time: 5.996
# Imputing row 3001/5760 with 5 missing columns, elapsed time: 6.018
# Imputing row 3101/5760 with 5 missing columns, elapsed time: 6.035
# Imputing row 3201/5760 with 5 missing columns, elapsed time: 6.049
# Imputing row 3301/5760 with 5 missing columns, elapsed time: 6.065
# Imputing row 3401/5760 with 5 missing columns, elapsed time: 6.085
# Imputing row 3501/5760 with 5 missing columns, elapsed time: 6.100
# Imputing row 3601/5760 with 5 missing columns, elapsed time: 6.124
# Imputing row 3701/5760 with 5 missing columns, elapsed time: 6.144
# Imputing row 3801/5760 with 5 missing columns, elapsed time: 6.157
# Imputing row 3901/5760 with 5 missing columns, elapsed time: 6.173
# Imputing row 4001/5760 with 5 missing columns, elapsed time: 6.189
# Imputing row 4101/5760 with 5 missing columns, elapsed time: 6.204
# Imputing row 4201/5760 with 5 missing columns, elapsed time: 6.217
# Imputing row 4301/5760 with 5 missing columns, elapsed time: 6.233
# Imputing row 4401/5760 with 5 missing columns, elapsed time: 6.248
# Imputing row 4501/5760 with 5 missing columns, elapsed time: 6.264
# Imputing row 4601/5760 with 5 missing columns, elapsed time: 6.278
# Imputing row 4701/5760 with 5 missing columns, elapsed time: 6.297
# Imputing row 4801/5760 with 5 missing columns, elapsed time: 6.313
# Imputing row 4901/5760 with 5 missing columns, elapsed time: 6.328
# Imputing row 5001/5760 with 5 missing columns, elapsed time: 6.349
# Imputing row 5101/5760 with 5 missing columns, elapsed time: 6.366
# Imputing row 5201/5760 with 5 missing columns, elapsed time: 6.379
# Imputing row 5301/5760 with 5 missing columns, elapsed time: 6.397
# Imputing row 5401/5760 with 5 missing columns, elapsed time: 6.414
# Imputing row 5501/5760 with 5 missing columns, elapsed time: 6.429
# Imputing row 5601/5760 with 5 missing columns, elapsed time: 6.440
# Imputing row 5701/5760 with 5 missing columns, elapsed time: 6.464
# 7200
# Computing pairwise distances between 7200 samples
# Computing distances for sample #1/7200, elapsed time: 1.169
# Computing distances for sample #101/7200, elapsed time: 1.245
# Computing distances for sample #201/7200, elapsed time: 1.333
# Computing distances for sample #301/7200, elapsed time: 1.411
# Computing distances for sample #401/7200, elapsed time: 1.488
# Computing distances for sample #501/7200, elapsed time: 1.569
# Computing distances for sample #601/7200, elapsed time: 1.673
# Computing distances for sample #701/7200, elapsed time: 1.750
# Computing distances for sample #801/7200, elapsed time: 1.829
# Computing distances for sample #901/7200, elapsed time: 1.914
# Computing distances for sample #1001/7200, elapsed time: 1.990
# Computing distances for sample #1101/7200, elapsed time: 2.075
# Computing distances for sample #1201/7200, elapsed time: 2.167
# Computing distances for sample #1301/7200, elapsed time: 2.236
# Computing distances for sample #1401/7200, elapsed time: 2.332
# Computing distances for sample #1501/7200, elapsed time: 2.413
# Computing distances for sample #1601/7200, elapsed time: 2.478
# Computing distances for sample #1701/7200, elapsed time: 2.570
# Computing distances for sample #1801/7200, elapsed time: 2.660
# Computing distances for sample #1901/7200, elapsed time: 2.736
# Computing distances for sample #2001/7200, elapsed time: 2.817
# Computing distances for sample #2101/7200, elapsed time: 2.901
# Computing distances for sample #2201/7200, elapsed time: 2.997
# Computing distances for sample #2301/7200, elapsed time: 3.071
# Computing distances for sample #2401/7200, elapsed time: 3.143
# Computing distances for sample #2501/7200, elapsed time: 3.224
# Computing distances for sample #2601/7200, elapsed time: 3.304
# Computing distances for sample #2701/7200, elapsed time: 3.392
# Computing distances for sample #2801/7200, elapsed time: 3.471
# Computing distances for sample #2901/7200, elapsed time: 3.569
# Computing distances for sample #3001/7200, elapsed time: 3.642
# Computing distances for sample #3101/7200, elapsed time: 3.722
# Computing distances for sample #3201/7200, elapsed time: 3.803
# Computing distances for sample #3301/7200, elapsed time: 3.887
# Computing distances for sample #3401/7200, elapsed time: 3.972
# Computing distances for sample #3501/7200, elapsed time: 4.048
# Computing distances for sample #3601/7200, elapsed time: 4.131
# Computing distances for sample #3701/7200, elapsed time: 4.205
# Computing distances for sample #3801/7200, elapsed time: 4.291
# Computing distances for sample #3901/7200, elapsed time: 4.371
# Computing distances for sample #4001/7200, elapsed time: 4.448
# Computing distances for sample #4101/7200, elapsed time: 4.528
# Computing distances for sample #4201/7200, elapsed time: 4.612
# Computing distances for sample #4301/7200, elapsed time: 4.693
# Computing distances for sample #4401/7200, elapsed time: 4.771
# Computing distances for sample #4501/7200, elapsed time: 4.849
# Computing distances for sample #4601/7200, elapsed time: 4.935
# Computing distances for sample #4701/7200, elapsed time: 5.036
# Computing distances for sample #4801/7200, elapsed time: 5.111
# Computing distances for sample #4901/7200, elapsed time: 5.201
# Computing distances for sample #5001/7200, elapsed time: 5.277
# Computing distances for sample #5101/7200, elapsed time: 5.371
# Computing distances for sample #5201/7200, elapsed time: 5.454
# Computing distances for sample #5301/7200, elapsed time: 5.534
# Computing distances for sample #5401/7200, elapsed time: 5.616
# Computing distances for sample #5501/7200, elapsed time: 5.720
# Computing distances for sample #5601/7200, elapsed time: 5.838
# Computing distances for sample #5701/7200, elapsed time: 5.964
# Computing distances for sample #5801/7200, elapsed time: 6.083
# Computing distances for sample #5901/7200, elapsed time: 6.206
# Computing distances for sample #6001/7200, elapsed time: 6.332
# Computing distances for sample #6101/7200, elapsed time: 6.448
# Computing distances for sample #6201/7200, elapsed time: 6.546
# Computing distances for sample #6301/7200, elapsed time: 6.658
# Computing distances for sample #6401/7200, elapsed time: 6.770
# Computing distances for sample #6501/7200, elapsed time: 6.892
# Computing distances for sample #6601/7200, elapsed time: 6.997
# Computing distances for sample #6701/7200, elapsed time: 7.088
# Computing distances for sample #6801/7200, elapsed time: 7.174
# Computing distances for sample #6901/7200, elapsed time: 7.251
# Computing distances for sample #7001/7200, elapsed time: 7.362
# Computing distances for sample #7101/7200, elapsed time: 7.449
# Imputing row 1/7200 with 5 missing columns, elapsed time: 9.788
# Imputing row 101/7200 with 5 missing columns, elapsed time: 9.818
# Imputing row 201/7200 with 5 missing columns, elapsed time: 9.842
# Imputing row 301/7200 with 5 missing columns, elapsed time: 9.865
# Imputing row 401/7200 with 5 missing columns, elapsed time: 9.891
# Imputing row 501/7200 with 5 missing columns, elapsed time: 9.914
# Imputing row 601/7200 with 5 missing columns, elapsed time: 9.938
# Imputing row 701/7200 with 5 missing columns, elapsed time: 9.961
# Imputing row 801/7200 with 5 missing columns, elapsed time: 9.979
# Imputing row 901/7200 with 5 missing columns, elapsed time: 9.998
# Imputing row 1001/7200 with 5 missing columns, elapsed time: 10.021
# Imputing row 1101/7200 with 5 missing columns, elapsed time: 10.038
# Imputing row 1201/7200 with 5 missing columns, elapsed time: 10.057
# Imputing row 1301/7200 with 5 missing columns, elapsed time: 10.084
# Imputing row 1401/7200 with 5 missing columns, elapsed time: 10.101
# Imputing row 1501/7200 with 5 missing columns, elapsed time: 10.120
# Imputing row 1601/7200 with 5 missing columns, elapsed time: 10.142
# Imputing row 1701/7200 with 5 missing columns, elapsed time: 10.159
# Imputing row 1801/7200 with 5 missing columns, elapsed time: 10.178
# Imputing row 1901/7200 with 5 missing columns, elapsed time: 10.203
# Imputing row 2001/7200 with 5 missing columns, elapsed time: 10.221
# Imputing row 2101/7200 with 5 missing columns, elapsed time: 10.238
# Imputing row 2201/7200 with 5 missing columns, elapsed time: 10.259
# Imputing row 2301/7200 with 5 missing columns, elapsed time: 10.276
# Imputing row 2401/7200 with 5 missing columns, elapsed time: 10.293
# Imputing row 2501/7200 with 5 missing columns, elapsed time: 10.311
# Imputing row 2601/7200 with 5 missing columns, elapsed time: 10.328
# Imputing row 2701/7200 with 5 missing columns, elapsed time: 10.350
# Imputing row 2801/7200 with 5 missing columns, elapsed time: 10.372
# Imputing row 2901/7200 with 5 missing columns, elapsed time: 10.391
# Imputing row 3001/7200 with 5 missing columns, elapsed time: 10.421
# Imputing row 3101/7200 with 5 missing columns, elapsed time: 10.438
# Imputing row 3201/7200 with 5 missing columns, elapsed time: 10.462
# Imputing row 3301/7200 with 5 missing columns, elapsed time: 10.489
# Imputing row 3401/7200 with 5 missing columns, elapsed time: 10.513
# Imputing row 3501/7200 with 5 missing columns, elapsed time: 10.541
# Imputing row 3601/7200 with 5 missing columns, elapsed time: 10.567
# Imputing row 3701/7200 with 5 missing columns, elapsed time: 10.589
# Imputing row 3801/7200 with 5 missing columns, elapsed time: 10.612
# Imputing row 3901/7200 with 5 missing columns, elapsed time: 10.630
# Imputing row 4001/7200 with 5 missing columns, elapsed time: 10.645
# Imputing row 4101/7200 with 5 missing columns, elapsed time: 10.671
# Imputing row 4201/7200 with 5 missing columns, elapsed time: 10.688
# Imputing row 4301/7200 with 5 missing columns, elapsed time: 10.704
# Imputing row 4401/7200 with 5 missing columns, elapsed time: 10.722
# Imputing row 4501/7200 with 5 missing columns, elapsed time: 10.743
# Imputing row 4601/7200 with 5 missing columns, elapsed time: 10.759
# Imputing row 4701/7200 with 5 missing columns, elapsed time: 10.777
# Imputing row 4801/7200 with 5 missing columns, elapsed time: 10.795
# Imputing row 4901/7200 with 5 missing columns, elapsed time: 10.811
# Imputing row 5001/7200 with 5 missing columns, elapsed time: 10.835
# Imputing row 5101/7200 with 5 missing columns, elapsed time: 10.856
# Imputing row 5201/7200 with 5 missing columns, elapsed time: 10.876
# Imputing row 5301/7200 with 5 missing columns, elapsed time: 10.895
# Imputing row 5401/7200 with 5 missing columns, elapsed time: 10.919
# Imputing row 5501/7200 with 5 missing columns, elapsed time: 10.936
# Imputing row 5601/7200 with 5 missing columns, elapsed time: 10.962
# Imputing row 5701/7200 with 5 missing columns, elapsed time: 10.985
# Imputing row 5801/7200 with 5 missing columns, elapsed time: 11.014
# Imputing row 5901/7200 with 5 missing columns, elapsed time: 11.043
# Imputing row 6001/7200 with 5 missing columns, elapsed time: 11.068
# Imputing row 6101/7200 with 5 missing columns, elapsed time: 11.098
# Imputing row 6201/7200 with 5 missing columns, elapsed time: 11.127
# Imputing row 6301/7200 with 5 missing columns, elapsed time: 11.156
# Imputing row 6401/7200 with 5 missing columns, elapsed time: 11.179
# Imputing row 6501/7200 with 5 missing columns, elapsed time: 11.206
# Imputing row 6601/7200 with 5 missing columns, elapsed time: 11.227
# Imputing row 6701/7200 with 5 missing columns, elapsed time: 11.256
# Imputing row 6801/7200 with 5 missing columns, elapsed time: 11.285
# Imputing row 6901/7200 with 5 missing columns, elapsed time: 11.312
# Imputing row 7001/7200 with 5 missing columns, elapsed time: 11.340
# Imputing row 7101/7200 with 5 missing columns, elapsed time: 11.362
# 8640
# Computing pairwise distances between 8640 samples
# Computing distances for sample #1/8640, elapsed time: 1.484
# Computing distances for sample #101/8640, elapsed time: 1.572
# Computing distances for sample #201/8640, elapsed time: 1.657
# Computing distances for sample #301/8640, elapsed time: 1.751
# Computing distances for sample #401/8640, elapsed time: 1.837
# Computing distances for sample #501/8640, elapsed time: 1.937
# Computing distances for sample #601/8640, elapsed time: 2.039
# Computing distances for sample #701/8640, elapsed time: 2.122
# Computing distances for sample #801/8640, elapsed time: 2.222
# Computing distances for sample #901/8640, elapsed time: 2.322
# Computing distances for sample #1001/8640, elapsed time: 2.407
# Computing distances for sample #1101/8640, elapsed time: 2.507
# Computing distances for sample #1201/8640, elapsed time: 2.605
# Computing distances for sample #1301/8640, elapsed time: 2.683
# Computing distances for sample #1401/8640, elapsed time: 2.783
# Computing distances for sample #1501/8640, elapsed time: 2.864
# Computing distances for sample #1601/8640, elapsed time: 2.959
# Computing distances for sample #1701/8640, elapsed time: 3.060
# Computing distances for sample #1801/8640, elapsed time: 3.146
# Computing distances for sample #1901/8640, elapsed time: 3.247
# Computing distances for sample #2001/8640, elapsed time: 3.348
# Computing distances for sample #2101/8640, elapsed time: 3.448
# Computing distances for sample #2201/8640, elapsed time: 3.544
# Computing distances for sample #2301/8640, elapsed time: 3.629
# Computing distances for sample #2401/8640, elapsed time: 3.723
# Computing distances for sample #2501/8640, elapsed time: 3.823
# Computing distances for sample #2601/8640, elapsed time: 3.907
# Computing distances for sample #2701/8640, elapsed time: 4.007
# Computing distances for sample #2801/8640, elapsed time: 4.107
# Computing distances for sample #2901/8640, elapsed time: 4.205
# Computing distances for sample #3001/8640, elapsed time: 4.289
# Computing distances for sample #3101/8640, elapsed time: 4.374
# Computing distances for sample #3201/8640, elapsed time: 4.474
# Computing distances for sample #3301/8640, elapsed time: 4.571
# Computing distances for sample #3401/8640, elapsed time: 4.656
# Computing distances for sample #3501/8640, elapsed time: 4.736
# Computing distances for sample #3601/8640, elapsed time: 4.838
# Computing distances for sample #3701/8640, elapsed time: 4.924
# Computing distances for sample #3801/8640, elapsed time: 5.024
# Computing distances for sample #3901/8640, elapsed time: 5.108
# Computing distances for sample #4001/8640, elapsed time: 5.208
# Computing distances for sample #4101/8640, elapsed time: 5.301
# Computing distances for sample #4201/8640, elapsed time: 5.399
# Computing distances for sample #4301/8640, elapsed time: 5.481
# Computing distances for sample #4401/8640, elapsed time: 5.583
# Computing distances for sample #4501/8640, elapsed time: 5.680
# Computing distances for sample #4601/8640, elapsed time: 5.764
# Computing distances for sample #4701/8640, elapsed time: 5.844
# Computing distances for sample #4801/8640, elapsed time: 5.945
# Computing distances for sample #4901/8640, elapsed time: 6.047
# Computing distances for sample #5001/8640, elapsed time: 6.146
# Computing distances for sample #5101/8640, elapsed time: 6.228
# Computing distances for sample #5201/8640, elapsed time: 6.330
# Computing distances for sample #5301/8640, elapsed time: 6.424
# Computing distances for sample #5401/8640, elapsed time: 6.509
# Computing distances for sample #5501/8640, elapsed time: 6.609
# Computing distances for sample #5601/8640, elapsed time: 6.690
# Computing distances for sample #5701/8640, elapsed time: 6.790
# Computing distances for sample #5801/8640, elapsed time: 6.890
# Computing distances for sample #5901/8640, elapsed time: 6.987
# Computing distances for sample #6001/8640, elapsed time: 7.073
# Computing distances for sample #6101/8640, elapsed time: 7.173
# Computing distances for sample #6201/8640, elapsed time: 7.275
# Computing distances for sample #6301/8640, elapsed time: 7.375
# Computing distances for sample #6401/8640, elapsed time: 7.471
# Computing distances for sample #6501/8640, elapsed time: 7.556
# Computing distances for sample #6601/8640, elapsed time: 7.652
# Computing distances for sample #6701/8640, elapsed time: 7.737
# Computing distances for sample #6801/8640, elapsed time: 7.825
# Computing distances for sample #6901/8640, elapsed time: 7.925
# Computing distances for sample #7001/8640, elapsed time: 8.025
# Computing distances for sample #7101/8640, elapsed time: 8.110
# Computing distances for sample #7201/8640, elapsed time: 8.209
# Computing distances for sample #7301/8640, elapsed time: 8.284
# Computing distances for sample #7401/8640, elapsed time: 8.381
# Computing distances for sample #7501/8640, elapsed time: 8.481
# Computing distances for sample #7601/8640, elapsed time: 8.562
# Computing distances for sample #7701/8640, elapsed time: 8.663
# Computing distances for sample #7801/8640, elapsed time: 8.744
# Computing distances for sample #7901/8640, elapsed time: 8.834
# Computing distances for sample #8001/8640, elapsed time: 8.927
# Computing distances for sample #8101/8640, elapsed time: 9.038
# Computing distances for sample #8201/8640, elapsed time: 9.131
# Computing distances for sample #8301/8640, elapsed time: 9.212
# Computing distances for sample #8401/8640, elapsed time: 9.312
# Computing distances for sample #8501/8640, elapsed time: 9.412
# Computing distances for sample #8601/8640, elapsed time: 9.512
# Imputing row 1/8640 with 5 missing columns, elapsed time: 12.484
# Imputing row 101/8640 with 5 missing columns, elapsed time: 12.514
# Imputing row 201/8640 with 5 missing columns, elapsed time: 12.539
# Imputing row 301/8640 with 5 missing columns, elapsed time: 12.559
# Imputing row 401/8640 with 5 missing columns, elapsed time: 12.580
# Imputing row 501/8640 with 5 missing columns, elapsed time: 12.598
# Imputing row 601/8640 with 5 missing columns, elapsed time: 12.621
# Imputing row 701/8640 with 5 missing columns, elapsed time: 12.640
# Imputing row 801/8640 with 5 missing columns, elapsed time: 12.657
# Imputing row 901/8640 with 5 missing columns, elapsed time: 12.679
# Imputing row 1001/8640 with 5 missing columns, elapsed time: 12.701
# Imputing row 1101/8640 with 5 missing columns, elapsed time: 12.717
# Imputing row 1201/8640 with 5 missing columns, elapsed time: 12.735
# Imputing row 1301/8640 with 5 missing columns, elapsed time: 12.754
# Imputing row 1401/8640 with 5 missing columns, elapsed time: 12.771
# Imputing row 1501/8640 with 5 missing columns, elapsed time: 12.795
# Imputing row 1601/8640 with 5 missing columns, elapsed time: 12.816
# Imputing row 1701/8640 with 5 missing columns, elapsed time: 12.834
# Imputing row 1801/8640 with 5 missing columns, elapsed time: 12.852
# Imputing row 1901/8640 with 5 missing columns, elapsed time: 12.873
# Imputing row 2001/8640 with 5 missing columns, elapsed time: 12.890
# Imputing row 2101/8640 with 5 missing columns, elapsed time: 12.908
# Imputing row 2201/8640 with 5 missing columns, elapsed time: 12.927
# Imputing row 2301/8640 with 5 missing columns, elapsed time: 12.944
# Imputing row 2401/8640 with 5 missing columns, elapsed time: 12.970
# Imputing row 2501/8640 with 5 missing columns, elapsed time: 12.992
# Imputing row 2601/8640 with 5 missing columns, elapsed time: 13.010
# Imputing row 2701/8640 with 5 missing columns, elapsed time: 13.029
# Imputing row 2801/8640 with 5 missing columns, elapsed time: 13.047
# Imputing row 2901/8640 with 5 missing columns, elapsed time: 13.065
# Imputing row 3001/8640 with 5 missing columns, elapsed time: 13.083
# Imputing row 3101/8640 with 5 missing columns, elapsed time: 13.101
# Imputing row 3201/8640 with 5 missing columns, elapsed time: 13.118
# Imputing row 3301/8640 with 5 missing columns, elapsed time: 13.136
# Imputing row 3401/8640 with 5 missing columns, elapsed time: 13.154
# Imputing row 3501/8640 with 5 missing columns, elapsed time: 13.171
# Imputing row 3601/8640 with 5 missing columns, elapsed time: 13.189
# Imputing row 3701/8640 with 5 missing columns, elapsed time: 13.209
# Imputing row 3801/8640 with 5 missing columns, elapsed time: 13.225
# Imputing row 3901/8640 with 5 missing columns, elapsed time: 13.244
# Imputing row 4001/8640 with 5 missing columns, elapsed time: 13.265
# Imputing row 4101/8640 with 5 missing columns, elapsed time: 13.282
# Imputing row 4201/8640 with 5 missing columns, elapsed time: 13.301
# Imputing row 4301/8640 with 5 missing columns, elapsed time: 13.327
# Imputing row 4401/8640 with 5 missing columns, elapsed time: 13.350
# Imputing row 4501/8640 with 5 missing columns, elapsed time: 13.377
# Imputing row 4601/8640 with 5 missing columns, elapsed time: 13.399
# Imputing row 4701/8640 with 5 missing columns, elapsed time: 13.419
# Imputing row 4801/8640 with 5 missing columns, elapsed time: 13.438
# Imputing row 4901/8640 with 5 missing columns, elapsed time: 13.457
# Imputing row 5001/8640 with 5 missing columns, elapsed time: 13.475
# Imputing row 5101/8640 with 5 missing columns, elapsed time: 13.493
# Imputing row 5201/8640 with 5 missing columns, elapsed time: 13.515
# Imputing row 5301/8640 with 5 missing columns, elapsed time: 13.533
# Imputing row 5401/8640 with 5 missing columns, elapsed time: 13.551
# Imputing row 5501/8640 with 5 missing columns, elapsed time: 13.570
# Imputing row 5601/8640 with 5 missing columns, elapsed time: 13.587
# Imputing row 5701/8640 with 5 missing columns, elapsed time: 13.607
# Imputing row 5801/8640 with 5 missing columns, elapsed time: 13.627
# Imputing row 5901/8640 with 5 missing columns, elapsed time: 13.644
# Imputing row 6001/8640 with 5 missing columns, elapsed time: 13.663
# Imputing row 6101/8640 with 5 missing columns, elapsed time: 13.683
# Imputing row 6201/8640 with 5 missing columns, elapsed time: 13.700
# Imputing row 6301/8640 with 5 missing columns, elapsed time: 13.722
# Imputing row 6401/8640 with 5 missing columns, elapsed time: 13.741
# Imputing row 6501/8640 with 5 missing columns, elapsed time: 13.759
# Imputing row 6601/8640 with 5 missing columns, elapsed time: 13.777
# Imputing row 6701/8640 with 5 missing columns, elapsed time: 13.800
# Imputing row 6801/8640 with 5 missing columns, elapsed time: 13.819
# Imputing row 6901/8640 with 5 missing columns, elapsed time: 13.839
# Imputing row 7001/8640 with 5 missing columns, elapsed time: 13.865
# Imputing row 7101/8640 with 5 missing columns, elapsed time: 13.882
# Imputing row 7201/8640 with 5 missing columns, elapsed time: 13.910
# Imputing row 7301/8640 with 5 missing columns, elapsed time: 13.928
# Imputing row 7401/8640 with 5 missing columns, elapsed time: 13.945
# Imputing row 7501/8640 with 5 missing columns, elapsed time: 13.972
# Imputing row 7601/8640 with 5 missing columns, elapsed time: 13.997
# Imputing row 7701/8640 with 5 missing columns, elapsed time: 14.016
# Imputing row 7801/8640 with 5 missing columns, elapsed time: 14.035
# Imputing row 7901/8640 with 5 missing columns, elapsed time: 14.052
# Imputing row 8001/8640 with 5 missing columns, elapsed time: 14.071
# Imputing row 8101/8640 with 5 missing columns, elapsed time: 14.092
# Imputing row 8201/8640 with 5 missing columns, elapsed time: 14.110
# Imputing row 8301/8640 with 5 missing columns, elapsed time: 14.128
# Imputing row 8401/8640 with 5 missing columns, elapsed time: 14.147
# Imputing row 8501/8640 with 5 missing columns, elapsed time: 14.164
# Imputing row 8601/8640 with 5 missing columns, elapsed time: 14.185
# 10080
# Computing pairwise distances between 10080 samples
# Computing distances for sample #1/10080, elapsed time: 2.004
# Computing distances for sample #101/10080, elapsed time: 2.123
# Computing distances for sample #201/10080, elapsed time: 2.242
# Computing distances for sample #301/10080, elapsed time: 2.342
# Computing distances for sample #401/10080, elapsed time: 2.442
# Computing distances for sample #501/10080, elapsed time: 2.558
# Computing distances for sample #601/10080, elapsed time: 2.673
# Computing distances for sample #701/10080, elapsed time: 2.773
# Computing distances for sample #801/10080, elapsed time: 2.890
# Computing distances for sample #901/10080, elapsed time: 2.991
# Computing distances for sample #1001/10080, elapsed time: 3.111
# Computing distances for sample #1101/10080, elapsed time: 3.227
# Computing distances for sample #1201/10080, elapsed time: 3.318
# Computing distances for sample #1301/10080, elapsed time: 3.433
# Computing distances for sample #1401/10080, elapsed time: 3.542
# Computing distances for sample #1501/10080, elapsed time: 3.642
# Computing distances for sample #1601/10080, elapsed time: 3.742
# Computing distances for sample #1701/10080, elapsed time: 3.858
# Computing distances for sample #1801/10080, elapsed time: 3.961
# Computing distances for sample #1901/10080, elapsed time: 4.078
# Computing distances for sample #2001/10080, elapsed time: 4.198
# Computing distances for sample #2101/10080, elapsed time: 4.298
# Computing distances for sample #2201/10080, elapsed time: 4.421
# Computing distances for sample #2301/10080, elapsed time: 4.521
# Computing distances for sample #2401/10080, elapsed time: 4.642
# Computing distances for sample #2501/10080, elapsed time: 4.743
# Computing distances for sample #2601/10080, elapsed time: 4.858
# Computing distances for sample #2701/10080, elapsed time: 4.959
# Computing distances for sample #2801/10080, elapsed time: 5.086
# Computing distances for sample #2901/10080, elapsed time: 5.185
# Computing distances for sample #3001/10080, elapsed time: 5.306
# Computing distances for sample #3101/10080, elapsed time: 5.407
# Computing distances for sample #3201/10080, elapsed time: 5.507
# Computing distances for sample #3301/10080, elapsed time: 5.614
# Computing distances for sample #3401/10080, elapsed time: 5.738
# Computing distances for sample #3501/10080, elapsed time: 5.848
# Computing distances for sample #3601/10080, elapsed time: 5.944
# Computing distances for sample #3701/10080, elapsed time: 6.059
# Computing distances for sample #3801/10080, elapsed time: 6.175
# Computing distances for sample #3901/10080, elapsed time: 6.277
# Computing distances for sample #4001/10080, elapsed time: 6.395
# Computing distances for sample #4101/10080, elapsed time: 6.498
# Computing distances for sample #4201/10080, elapsed time: 6.615
# Computing distances for sample #4301/10080, elapsed time: 6.720
# Computing distances for sample #4401/10080, elapsed time: 6.843
# Computing distances for sample #4501/10080, elapsed time: 6.945
# Computing distances for sample #4601/10080, elapsed time: 7.060
# Computing distances for sample #4701/10080, elapsed time: 7.179
# Computing distances for sample #4801/10080, elapsed time: 7.285
# Computing distances for sample #4901/10080, elapsed time: 7.387
# Computing distances for sample #5001/10080, elapsed time: 7.502
# Computing distances for sample #5101/10080, elapsed time: 7.622
# Computing distances for sample #5201/10080, elapsed time: 7.724
# Computing distances for sample #5301/10080, elapsed time: 7.828
# Computing distances for sample #5401/10080, elapsed time: 7.946
# Computing distances for sample #5501/10080, elapsed time: 8.046
# Computing distances for sample #5601/10080, elapsed time: 8.161
# Computing distances for sample #5701/10080, elapsed time: 8.272
# Computing distances for sample #5801/10080, elapsed time: 8.388
# Computing distances for sample #5901/10080, elapsed time: 8.493
# Computing distances for sample #6001/10080, elapsed time: 8.625
# Computing distances for sample #6101/10080, elapsed time: 8.777
# Computing distances for sample #6201/10080, elapsed time: 8.906
# Computing distances for sample #6301/10080, elapsed time: 9.062
# Computing distances for sample #6401/10080, elapsed time: 9.193
# Computing distances for sample #6501/10080, elapsed time: 9.314
# Computing distances for sample #6601/10080, elapsed time: 9.462
# Computing distances for sample #6701/10080, elapsed time: 9.597
# Computing distances for sample #6801/10080, elapsed time: 9.744
# Computing distances for sample #6901/10080, elapsed time: 9.847
# Computing distances for sample #7001/10080, elapsed time: 9.947
# Computing distances for sample #7101/10080, elapsed time: 10.063
# Computing distances for sample #7201/10080, elapsed time: 10.163
# Computing distances for sample #7301/10080, elapsed time: 10.280
# Computing distances for sample #7401/10080, elapsed time: 10.401
# Computing distances for sample #7501/10080, elapsed time: 10.503
# Computing distances for sample #7601/10080, elapsed time: 10.623
# Computing distances for sample #7701/10080, elapsed time: 10.723
# Computing distances for sample #7801/10080, elapsed time: 10.848
# Computing distances for sample #7901/10080, elapsed time: 10.964
# Computing distances for sample #8001/10080, elapsed time: 11.079
# Computing distances for sample #8101/10080, elapsed time: 11.187
# Computing distances for sample #8201/10080, elapsed time: 11.287
# Computing distances for sample #8301/10080, elapsed time: 11.408
# Computing distances for sample #8401/10080, elapsed time: 11.509
# Computing distances for sample #8501/10080, elapsed time: 11.614
# Computing distances for sample #8601/10080, elapsed time: 11.730
# Computing distances for sample #8701/10080, elapsed time: 11.849
# Computing distances for sample #8801/10080, elapsed time: 11.965
# Computing distances for sample #8901/10080, elapsed time: 12.080
# Computing distances for sample #9001/10080, elapsed time: 12.194
# Computing distances for sample #9101/10080, elapsed time: 12.295
# Computing distances for sample #9201/10080, elapsed time: 12.399
# Computing distances for sample #9301/10080, elapsed time: 12.515
# Computing distances for sample #9401/10080, elapsed time: 12.621
# Computing distances for sample #9501/10080, elapsed time: 12.722
# Computing distances for sample #9601/10080, elapsed time: 12.843
# Computing distances for sample #9701/10080, elapsed time: 12.950
# Computing distances for sample #9801/10080, elapsed time: 13.050
# Computing distances for sample #9901/10080, elapsed time: 13.166
# Computing distances for sample #10001/10080, elapsed time: 13.281
# Imputing row 1/10080 with 5 missing columns, elapsed time: 17.438
# Imputing row 101/10080 with 5 missing columns, elapsed time: 17.463
# Imputing row 201/10080 with 5 missing columns, elapsed time: 17.485
# Imputing row 301/10080 with 5 missing columns, elapsed time: 17.504
# Imputing row 401/10080 with 5 missing columns, elapsed time: 17.535
# Imputing row 501/10080 with 5 missing columns, elapsed time: 17.562
# Imputing row 601/10080 with 5 missing columns, elapsed time: 17.582
# Imputing row 701/10080 with 5 missing columns, elapsed time: 17.604
# Imputing row 801/10080 with 5 missing columns, elapsed time: 17.623
# Imputing row 901/10080 with 5 missing columns, elapsed time: 17.645
# Imputing row 1001/10080 with 5 missing columns, elapsed time: 17.665
# Imputing row 1101/10080 with 5 missing columns, elapsed time: 17.684
# Imputing row 1201/10080 with 5 missing columns, elapsed time: 17.704
# Imputing row 1301/10080 with 5 missing columns, elapsed time: 17.735
# Imputing row 1401/10080 with 5 missing columns, elapsed time: 17.757
# Imputing row 1501/10080 with 5 missing columns, elapsed time: 17.783
# Imputing row 1601/10080 with 5 missing columns, elapsed time: 17.801
# Imputing row 1701/10080 with 5 missing columns, elapsed time: 17.821
# Imputing row 1801/10080 with 5 missing columns, elapsed time: 17.841
# Imputing row 1901/10080 with 5 missing columns, elapsed time: 17.860
# Imputing row 2001/10080 with 5 missing columns, elapsed time: 17.883
# ...
# Computing distances for sample #2301/12960, elapsed time: 7.260
# Computing distances for sample #2401/12960, elapsed time: 7.400
# Computing distances for sample #2501/12960, elapsed time: 7.593
# Computing distances for sample #2601/12960, elapsed time: 7.772
# Computing distances for sample #2701/12960, elapsed time: 7.901
# Computing distances for sample #2801/12960, elapsed time: 8.072
# Computing distances for sample #2901/12960, elapsed time: 8.258
# Computing distances for sample #3001/12960, elapsed time: 8.441
# Computing distances for sample #3101/12960, elapsed time: 8.628
# Computing distances for sample #3201/12960, elapsed time: 8.756
# Computing distances for sample #3301/12960, elapsed time: 8.932
# Computing distances for sample #3401/12960, elapsed time: 9.120
# Computing distances for sample #3501/12960, elapsed time: 9.287
# Computing distances for sample #3601/12960, elapsed time: 9.431
# Computing distances for sample #3701/12960, elapsed time: 9.621
# Computing distances for sample #3801/12960, elapsed time: 9.788
# Computing distances for sample #3901/12960, elapsed time: 9.919
# Computing distances for sample #4001/12960, elapsed time: 10.056
# Computing distances for sample #4101/12960, elapsed time: 10.231
# Computing distances for sample #4201/12960, elapsed time: 10.421
# Computing distances for sample #4301/12960, elapsed time: 10.593
# Computing distances for sample #4401/12960, elapsed time: 10.725
# Computing distances for sample #4501/12960, elapsed time: 10.870
# Computing distances for sample #4601/12960, elapsed time: 11.018
# Computing distances for sample #4701/12960, elapsed time: 11.163
# Computing distances for sample #4801/12960, elapsed time: 11.318
# Computing distances for sample #4901/12960, elapsed time: 11.481
# Computing distances for sample #5001/12960, elapsed time: 11.679
# Computing distances for sample #5101/12960, elapsed time: 11.835
# Computing distances for sample #5201/12960, elapsed time: 12.001
# Computing distances for sample #5301/12960, elapsed time: 12.160
# Computing distances for sample #5401/12960, elapsed time: 12.337
# Computing distances for sample #5501/12960, elapsed time: 12.540
# Computing distances for sample #5601/12960, elapsed time: 12.706
# Computing distances for sample #5701/12960, elapsed time: 12.887
# Computing distances for sample #5801/12960, elapsed time: 13.047
# Computing distances for sample #5901/12960, elapsed time: 13.223
# Computing distances for sample #6001/12960, elapsed time: 13.372
# Computing distances for sample #6101/12960, elapsed time: 13.542
# Computing distances for sample #6201/12960, elapsed time: 13.730
# Computing distances for sample #6301/12960, elapsed time: 13.891
# Computing distances for sample #6401/12960, elapsed time: 14.058
# Computing distances for sample #6501/12960, elapsed time: 14.240
# Computing distances for sample #6601/12960, elapsed time: 14.390
# Computing distances for sample #6701/12960, elapsed time: 14.547
# Computing distances for sample #6801/12960, elapsed time: 14.690
# Computing distances for sample #6901/12960, elapsed time: 14.882
# Computing distances for sample #7001/12960, elapsed time: 15.055
# Computing distances for sample #7101/12960, elapsed time: 15.206
# Computing distances for sample #7201/12960, elapsed time: 15.351
# Computing distances for sample #7301/12960, elapsed time: 15.506
# Computing distances for sample #7401/12960, elapsed time: 15.653
# Computing distances for sample #7501/12960, elapsed time: 15.806
# Computing distances for sample #7601/12960, elapsed time: 15.961
# Computing distances for sample #7701/12960, elapsed time: 16.122
# Computing distances for sample #7801/12960, elapsed time: 16.281
# Computing distances for sample #7901/12960, elapsed time: 16.423
# Computing distances for sample #8001/12960, elapsed time: 16.591
# Computing distances for sample #8101/12960, elapsed time: 16.746
# Computing distances for sample #8201/12960, elapsed time: 16.907
# Computing distances for sample #8301/12960, elapsed time: 17.043
# Computing distances for sample #8401/12960, elapsed time: 17.192
# Computing distances for sample #8501/12960, elapsed time: 17.335
# Computing distances for sample #8601/12960, elapsed time: 17.508
# Computing distances for sample #8701/12960, elapsed time: 17.653
# Computing distances for sample #8801/12960, elapsed time: 17.793
# Computing distances for sample #8901/12960, elapsed time: 17.938
# Computing distances for sample #9001/12960, elapsed time: 18.109
# Computing distances for sample #9101/12960, elapsed time: 18.251
# Computing distances for sample #9201/12960, elapsed time: 18.393
# Computing distances for sample #9301/12960, elapsed time: 18.554
# Computing distances for sample #9401/12960, elapsed time: 18.693
# Computing distances for sample #9501/12960, elapsed time: 18.840
# Computing distances for sample #9601/12960, elapsed time: 18.984
# Computing distances for sample #9701/12960, elapsed time: 19.109
# Computing distances for sample #9801/12960, elapsed time: 19.280
# Computing distances for sample #9901/12960, elapsed time: 19.410
# Computing distances for sample #10001/12960, elapsed time: 19.564
# Computing distances for sample #10101/12960, elapsed time: 19.710
# Computing distances for sample #10201/12960, elapsed time: 19.862
# Computing distances for sample #10301/12960, elapsed time: 20.010
# Computing distances for sample #10401/12960, elapsed time: 20.137
# Computing distances for sample #10501/12960, elapsed time: 20.295
# Computing distances for sample #10601/12960, elapsed time: 20.431
# Computing distances for sample #10701/12960, elapsed time: 20.596
# Computing distances for sample #10801/12960, elapsed time: 20.733
# Computing distances for sample #10901/12960, elapsed time: 20.890
# Computing distances for sample #11001/12960, elapsed time: 21.055
# Computing distances for sample #11101/12960, elapsed time: 21.211
# Computing distances for sample #11201/12960, elapsed time: 21.358
# Computing distances for sample #11301/12960, elapsed time: 21.511
# Computing distances for sample #11401/12960, elapsed time: 21.660
# Computing distances for sample #11501/12960, elapsed time: 21.820
# Computing distances for sample #11601/12960, elapsed time: 21.956
# Computing distances for sample #11701/12960, elapsed time: 22.111
# Computing distances for sample #11801/12960, elapsed time: 22.295
# Computing distances for sample #11901/12960, elapsed time: 22.489
# Computing distances for sample #12001/12960, elapsed time: 22.659
# Computing distances for sample #12101/12960, elapsed time: 22.795
# Computing distances for sample #12201/12960, elapsed time: 22.978
# Computing distances for sample #12301/12960, elapsed time: 23.179
# Computing distances for sample #12401/12960, elapsed time: 23.340
# Computing distances for sample #12501/12960, elapsed time: 23.524
# Computing distances for sample #12601/12960, elapsed time: 23.704
# Computing distances for sample #12701/12960, elapsed time: 23.850
# Computing distances for sample #12801/12960, elapsed time: 23.997
# Computing distances for sample #12901/12960, elapsed time: 24.157
# Imputing row 1/12960 with 5 missing columns, elapsed time: 33.088
# Imputing row 101/12960 with 5 missing columns, elapsed time: 33.123
# Imputing row 201/12960 with 5 missing columns, elapsed time: 33.148
# Imputing row 301/12960 with 5 missing columns, elapsed time: 33.183
# Imputing row 401/12960 with 5 missing columns, elapsed time: 33.210
# Imputing row 501/12960 with 5 missing columns, elapsed time: 33.240
# Imputing row 601/12960 with 5 missing columns, elapsed time: 33.264
# Imputing row 701/12960 with 5 missing columns, elapsed time: 33.291
# Imputing row 801/12960 with 5 missing columns, elapsed time: 33.320
# Imputing row 901/12960 with 5 missing columns, elapsed time: 33.343
# Imputing row 1001/12960 with 5 missing columns, elapsed time: 33.373
# Imputing row 1101/12960 with 5 missing columns, elapsed time: 33.396
# Imputing row 1201/12960 with 5 missing columns, elapsed time: 33.431
# Imputing row 1301/12960 with 5 missing columns, elapsed time: 33.459
# Imputing row 1401/12960 with 5 missing columns, elapsed time: 33.487
# Imputing row 1501/12960 with 5 missing columns, elapsed time: 33.524
# Imputing row 1601/12960 with 5 missing columns, elapsed time: 33.558
# Imputing row 1701/12960 with 5 missing columns, elapsed time: 33.592
# Imputing row 1801/12960 with 5 missing columns, elapsed time: 33.624
# Imputing row 1901/12960 with 5 missing columns, elapsed time: 33.657
# Imputing row 2001/12960 with 5 missing columns, elapsed time: 33.687
# Imputing row 2101/12960 with 5 missing columns, elapsed time: 33.710
# Imputing row 2201/12960 with 5 missing columns, elapsed time: 33.731
# Imputing row 2301/12960 with 5 missing columns, elapsed time: 33.755
# Imputing row 2401/12960 with 5 missing columns, elapsed time: 33.788
# Imputing row 2501/12960 with 5 missing columns, elapsed time: 33.818
# Imputing row 2601/12960 with 5 missing columns, elapsed time: 33.840
# Imputing row 2701/12960 with 5 missing columns, elapsed time: 33.862
# Imputing row 2801/12960 with 5 missing columns, elapsed time: 33.886
# Imputing row 2901/12960 with 5 missing columns, elapsed time: 33.914
# Imputing row 3001/12960 with 5 missing columns, elapsed time: 33.939
# Imputing row 3101/12960 with 5 missing columns, elapsed time: 33.961
# Imputing row 3201/12960 with 5 missing columns, elapsed time: 33.988
# Imputing row 3301/12960 with 5 missing columns, elapsed time: 34.013
# Imputing row 3401/12960 with 5 missing columns, elapsed time: 34.043
# Imputing row 3501/12960 with 5 missing columns, elapsed time: 34.070
# Imputing row 3601/12960 with 5 missing columns, elapsed time: 34.093
# Imputing row 3701/12960 with 5 missing columns, elapsed time: 34.115
# Imputing row 3801/12960 with 5 missing columns, elapsed time: 34.148
# Imputing row 3901/12960 with 5 missing columns, elapsed time: 34.171
# Imputing row 4001/12960 with 5 missing columns, elapsed time: 34.205
# Imputing row 4101/12960 with 5 missing columns, elapsed time: 34.228
# Imputing row 4201/12960 with 5 missing columns, elapsed time: 34.252
# Imputing row 4301/12960 with 5 missing columns, elapsed time: 34.284
# Imputing row 4401/12960 with 5 missing columns, elapsed time: 34.312
# Imputing row 4501/12960 with 5 missing columns, elapsed time: 34.343
# Imputing row 4601/12960 with 5 missing columns, elapsed time: 34.366
# Imputing row 4701/12960 with 5 missing columns, elapsed time: 34.393
# Imputing row 4801/12960 with 5 missing columns, elapsed time: 34.419
# Imputing row 4901/12960 with 5 missing columns, elapsed time: 34.451
# Imputing row 5001/12960 with 5 missing columns, elapsed time: 34.475
# Imputing row 5101/12960 with 5 missing columns, elapsed time: 34.504
# Imputing row 5201/12960 with 5 missing columns, elapsed time: 34.536
# Imputing row 5301/12960 with 5 missing columns, elapsed time: 34.565
# Imputing row 5401/12960 with 5 missing columns, elapsed time: 34.594
# Imputing row 5501/12960 with 5 missing columns, elapsed time: 34.624
# Imputing row 5601/12960 with 5 missing columns, elapsed time: 34.646
# Imputing row 5701/12960 with 5 missing columns, elapsed time: 34.668
# Imputing row 5801/12960 with 5 missing columns, elapsed time: 34.693
# Imputing row 5901/12960 with 5 missing columns, elapsed time: 34.714
# Imputing row 6001/12960 with 5 missing columns, elapsed time: 34.743
# Imputing row 6101/12960 with 5 missing columns, elapsed time: 34.767
# Imputing row 6201/12960 with 5 missing columns, elapsed time: 34.797
# Imputing row 6301/12960 with 5 missing columns, elapsed time: 34.825
# Imputing row 6401/12960 with 5 missing columns, elapsed time: 34.853
# Imputing row 6501/12960 with 5 missing columns, elapsed time: 34.884
# Imputing row 6601/12960 with 5 missing columns, elapsed time: 34.908
# Imputing row 6701/12960 with 5 missing columns, elapsed time: 34.938
# Imputing row 6801/12960 with 5 missing columns, elapsed time: 34.968
# Imputing row 6901/12960 with 5 missing columns, elapsed time: 35.002
# Imputing row 7001/12960 with 5 missing columns, elapsed time: 35.037
# Imputing row 7101/12960 with 5 missing columns, elapsed time: 35.062
# Imputing row 7201/12960 with 5 missing columns, elapsed time: 35.087
# Imputing row 7301/12960 with 5 missing columns, elapsed time: 35.122
# Imputing row 7401/12960 with 5 missing columns, elapsed time: 35.145
# Imputing row 7501/12960 with 5 missing columns, elapsed time: 35.175
# Imputing row 7601/12960 with 5 missing columns, elapsed time: 35.203
# Imputing row 7701/12960 with 5 missing columns, elapsed time: 35.230
# Imputing row 7801/12960 with 5 missing columns, elapsed time: 35.263
# Imputing row 7901/12960 with 5 missing columns, elapsed time: 35.292
# Imputing row 8001/12960 with 5 missing columns, elapsed time: 35.314
# Imputing row 8101/12960 with 5 missing columns, elapsed time: 35.346
# Imputing row 8201/12960 with 5 missing columns, elapsed time: 35.371
# Imputing row 8301/12960 with 5 missing columns, elapsed time: 35.399
# Imputing row 8401/12960 with 5 missing columns, elapsed time: 35.421
# Imputing row 8501/12960 with 5 missing columns, elapsed time: 35.443
# Imputing row 8601/12960 with 5 missing columns, elapsed time: 35.465
# Imputing row 8701/12960 with 5 missing columns, elapsed time: 35.492
# Imputing row 8801/12960 with 5 missing columns, elapsed time: 35.517
# Imputing row 8901/12960 with 5 missing columns, elapsed time: 35.545
# Imputing row 9001/12960 with 5 missing columns, elapsed time: 35.577
# Imputing row 9101/12960 with 5 missing columns, elapsed time: 35.601
# Imputing row 9201/12960 with 5 missing columns, elapsed time: 35.628
# Imputing row 9301/12960 with 5 missing columns, elapsed time: 35.655
# Imputing row 9401/12960 with 5 missing columns, elapsed time: 35.683
# Imputing row 9501/12960 with 5 missing columns, elapsed time: 35.710
# Imputing row 9601/12960 with 5 missing columns, elapsed time: 35.739
# Imputing row 9701/12960 with 5 missing columns, elapsed time: 35.764
# Imputing row 9801/12960 with 5 missing columns, elapsed time: 35.792
# Imputing row 9901/12960 with 5 missing columns, elapsed time: 35.817
# Imputing row 10001/12960 with 5 missing columns, elapsed time: 35.846
# Imputing row 10101/12960 with 5 missing columns, elapsed time: 35.872
# Imputing row 10201/12960 with 5 missing columns, elapsed time: 35.904
# Imputing row 10301/12960 with 5 missing columns, elapsed time: 35.928
# Imputing row 10401/12960 with 5 missing columns, elapsed time: 35.954
# Imputing row 10501/12960 with 5 missing columns, elapsed time: 35.984
# Imputing row 10601/12960 with 5 missing columns, elapsed time: 36.012
# Imputing row 10701/12960 with 5 missing columns, elapsed time: 36.044
# Imputing row 10801/12960 with 5 missing columns, elapsed time: 36.067
# Imputing row 10901/12960 with 5 missing columns, elapsed time: 36.091
# Imputing row 11001/12960 with 5 missing columns, elapsed time: 36.117
# Imputing row 11101/12960 with 5 missing columns, elapsed time: 36.146
# Imputing row 11201/12960 with 5 missing columns, elapsed time: 36.179
# Imputing row 11301/12960 with 5 missing columns, elapsed time: 36.203
# Imputing row 11401/12960 with 5 missing columns, elapsed time: 36.227
# Imputing row 11501/12960 with 5 missing columns, elapsed time: 36.248
# Imputing row 11601/12960 with 5 missing columns, elapsed time: 36.281
# Imputing row 11701/12960 with 5 missing columns, elapsed time: 36.303
# Imputing row 11801/12960 with 5 missing columns, elapsed time: 36.327
# Imputing row 11901/12960 with 5 missing columns, elapsed time: 36.350
# Imputing row 12001/12960 with 5 missing columns, elapsed time: 36.375
# Imputing row 12101/12960 with 5 missing columns, elapsed time: 36.399
# Imputing row 12201/12960 with 5 missing columns, elapsed time: 36.427
# Imputing row 12301/12960 with 5 missing columns, elapsed time: 36.450
# Imputing row 12401/12960 with 5 missing columns, elapsed time: 36.476
# Imputing row 12501/12960 with 5 missing columns, elapsed time: 36.500
# Imputing row 12601/12960 with 5 missing columns, elapsed time: 36.528
# Imputing row 12701/12960 with 5 missing columns, elapsed time: 36.550
# Imputing row 12801/12960 with 5 missing columns, elapsed time: 36.577
# Imputing row 12901/12960 with 5 missing columns, elapsed time: 36.606

# %%
fig3 = plt.figure(figsize=(10,5))
ax = fig3.add_subplot(1, 1, 1)
#ax.plot(mobiledata_fs['minute'][pd.notnull(mobiledata_fs['tzone'])], 'k.')
#ax.plot(pd.notnull(mobiledata_fs['tzone']), 'k.')
#ax.set_yticks([0, 1, 2])
ax.plot(knn_all_PR, label='NN', color="g")
ax.plot(rdg_all_PR, label='Ridge', color="b")
ax.plot(rf_all_PR, label='RF', color="y")
ax.plot(gb_all_PR, label='GBDT', color="r")
ax.set_yticks([0, 0.2, 0.4, 0.6, 0.8, 1])
ax.set_ylabel("precision")
ax.set_xlabel("Call Frequency - number of calls per day")
ax.set_xticklabels(range(1,10))
ax.legend(loc='best')

# %%
knn_all_PR
# Out:
# [1.0,
#  0.99583333333333335,
#  0.99444444444444446,
#  0.99444444444444446,
#  0.99388888888888893,
#  0.99398148148148147,
#  0.99285714285714288,
#  0.99201388888888886,
#  0.98950617283950615]

# %%
t = NL_ML(comdata_fs_filled)

# %%
print gb_all_PR
# Out:
# [1.0, 1.0, 0.99972222222222218, 0.99944444444444447, 0.99972222222222218, 0.99944444444444447, 0.99972222222222218, 0.99972222222222218, 1.0]

# %%
print t
# Out:
# (1.0, array([[2704,    0,    0],
#        [   0,  777,    0],
#        [   0,    0,  119]]), 1.0, array([[2704,    0,    0],
#        [   0,  777,    0],
#        [   0,    0,  119]]), 1.0, array([[2704,    0,    0],
#        [   0,  777,    0],
#        [   0,    0,  119]]), 1.0, array([[2704,    0,    0],
#        [   0,  777,    0],
#        [   0,    0,  119]]))

# %%
# prepare for ML

X = mobiledata_fs_filled.drop('zone', axis=1)
y = mobiledata_fs_filled['zone']

trainX, testX, trainY, testY = train_test_split(X, y)

# %%
## using KNN
# weights might need to be changed - more weights towards the recent data?
# metrics? canberra, minkowski


clf_knn = KNeighborsClassifier(n_neighbors=1).fit(trainX, trainY)
pred_knn = clf_knn.predict(testX)
#print roc_auc_score(testY, pred_knn)
print precision_score(testY, pred_knn, average='micro')  
print recall_score(testY, pred_knn, average='micro')
confusion_matrix(testY, pred_knn)
# Out:
# 0.994444444444
# 0.994444444444
# array([[214,   0,   0,   0],
#        [  0, 103,   1,   0],
#        [  0,   0,  25,   0],
#        [  1,   0,   0,  16]])

# %%
pred_knn.shape
# Out:
# (360L,)

# %%
testX, pred_knn
# Out:
# (       acc_time  day  minute  pid  tid  status       xcor       ycor  tpid  \
#  189         189    0     189  441  453       0  30.000000 -37.000000     0
#  11355     11355    7    1275  441  453       0  29.498438 -37.250781     0
#  11350     11350    7    1270  441  453       0  29.498438 -37.250781     0
#  11457     11457    7    1377  441  453       0  29.498438 -37.250781     0
#  656         656    0     656  441  470       0 -32.000000  22.236068     0
#  509         509    0     509  441  447       1  20.000000 -20.236068     0
#  6318       6318    4     558  441  465       1  -0.980256   8.000000     0
#  11575     11575    8      55  441  453       0  29.498438 -37.250781     0
#  11946     11946    8     426  441  453       0  29.498438 -37.250781     0
#  3303       3303    2     423  441  453       0  29.205262 -37.397369     0
#  11993     11993    8     473  441  453       0  29.498438 -37.250781     0
#  1059       1059    0    1059  441  450       1 -36.000000  -5.291796     0
#  6793       6793    4    1033  441  470       1 -36.000000  12.491880     0
#  6970       6970    4    1210  441  453       0  29.348903 -37.325548     0
#  5575       5575    3    1255  441  453       0  30.245188 -37.000000     0
#  4814       4814    3     494  441  449       1  24.000000 -30.536984     0
#  8569       8569    5    1369  441  453       0  29.398748 -37.300626     0
#  9717       9717    6    1077  441  464       0 -32.000000 -10.380424     0
#  3755       3755    2     875  441  465       1   8.000000  11.596748     0
#  8330       8330    5    1130  441  452       1  -4.436152  -8.000000     0
#  2890       2890    2      10  441  453       0  29.205262 -37.397369     0
#  13658     13658    9     698  441  470       0 -32.000000  22.741104     0
#  742         742    0     742  441  470       1 -27.236068  12.000000     0
#  12271     12271    8     751  441  458       1 -10.796832  12.000000     0
#  823         823    0     823  441  454       0  30.788854  22.422291     0
#  8999       8999    6     359  441  453       0  29.398748 -37.300626     0
#  12526     12526    8    1006  441  470       0 -32.000000  22.268968     0
#  2809       2809    1    1369  441  453       0  29.205262 -37.397369     0
#  10825     10825    7     745  441  470       1 -24.852560  12.000000     0
#  8227       8227    5    1027  441  470       1 -36.000000  18.436152     0
#  ...         ...  ...     ...  ...  ...     ...        ...        ...   ...
#  7781       7781    5     581  441  458       1 -19.035984  12.000000     0
#  5213       5213    3     893  441  465       1  -4.000000   9.990880     0
#  4598       4598    3     278  441  453       0  30.832816 -37.000000     0
#  13120     13120    9     160  441  453       0  29.548282 -37.225859     0
#  705         705    0     705  441  470       0 -32.000000  22.236068     0
#  3007       3007    2     127  441  453       0  29.205262 -37.397369     0
#  109         109    0     109  441  453       0  30.000000 -37.000000     0
#  9121       9121    6     481  441  453       1  31.187603 -36.406199     0
#  3873       3873    2     993  441  470       0 -32.000000  22.596748     0
#  11956     11956    8     436  441  453       0  29.498438 -37.250781     0
#  10744     10744    7     664  441  470       0 -32.000000  22.852560     0
#  6412       6412    4     652  441  470       0 -32.000000  22.019744     0
#  13437     13437    9     477  441  453       0  29.548282 -37.225859     0
#  8532       8532    5    1332  441  453       0  29.398748 -37.300626     0
#  7175       7175    4    1415  441  453       0  29.348903 -37.325548     0
#  13664     13664    9     704  441  470       0 -32.000000  22.741104     0
#  10377     10377    7     297  441  453       0  29.448593 -37.275704     0
#  3093       3093    2     213  441  453       0  29.205262 -37.397369     0
#  5231       5231    3     911  441  458       1 -19.990880  12.000000     0
#  2992       2992    2     112  441  453       0  29.205262 -37.397369     0
#  2709       2709    1    1269  441  453       0  29.205262 -37.397369     0
#  1086       1086    0    1086  441  464       0 -32.000000 -10.708204     0
#  12657     12657    8    1137  441  457       1  -1.268968 -12.000000     0
#  4146       4146    2    1266  441  453       0  30.832816 -37.000000     0
#  12603     12603    8    1083  441  464       0 -32.000000 -10.268968     0
#  111         111    0     111  441  453       0  30.000000 -37.000000     0
#  1191       1191    0    1191  441  453       1  28.291796 -36.000000     0
#  10975     10975    7     895  441  465       1  -4.675304  12.000000     0
#  675         675    0     675  441  470       0 -32.000000  22.236068     0
#  8518       8518    5    1318  441  453       0  29.398748 -37.300626     0
#
#         tzone   radius  txcor  tycor
#  189       25  9.52381    -16     16
#  11355     35  9.52381     32     16
#  11350     35  9.52381     32     16
#  11457     35  9.52381     32     16
#  656       25  9.52381    -16     16
#  509       25  9.52381    -16     16
#  6318      15  9.52381     32    -32
#  11575     35  9.52381     32     16
#  11946     35  9.52381     32     16
#  3303      15  9.52381     32    -32
#  11993     35  9.52381     32     16
#  1059      25  9.52381    -32     16
#  6793      15  9.52381     32    -32
#  6970      15  9.52381     32    -32
#  5575      15  9.52381     32    -32
#  4814      15  9.52381     32    -32
#  8569      35  9.52381     32     16
#  9717      35  9.52381     32     16
#  3755      15  9.52381     32    -32
#  8330      35  9.52381     32     16
#  2890      15  9.52381     32    -32
#  13658     35  9.52381     32     16
#  742       25  9.52381    -16     16
#  12271     35  9.52381     32     16
#  823       25  9.52381    -16     16
#  8999      35  9.52381     32     16
#  12526     35  9.52381     32     16
#  2809      15  9.52381     32    -32
#  10825     35  9.52381     32     16
#  8227      35  9.52381     32     16
#  ...      ...      ...    ...    ...
#  7781      35  9.52381     32     16
#  5213      15  9.52381     32    -32
#  4598      15  9.52381     32    -32
#  13120     35  9.52381     32     16
#  705       25  9.52381    -16     16
#  3007      15  9.52381     32    -32
#  109       25  9.52381    -16     16
#  9121      35  9.52381     32     16
#  3873      15  9.52381     32    -32
#  11956     35  9.52381     32     16
#  10744     35  9.52381     32     16
#  6412      15  9.52381     32    -32
#  13437     35  9.52381     32     16
#  8532      35  9.52381     32     16
#  7175      35  9.52381     32     16
#  13664     35  9.52381     32     16
#  10377     35  9.52381     32     16
#  3093      15  9.52381     32    -32
#  5231      15  9.52381     32    -32
#  2992      15  9.52381     32    -32
#  2709      15  9.52381     32    -32
#  1086      25  9.52381    -32     16
#  12657     35  9.52381     32     16
#  4146      15  9.52381     32    -32
#  12603     35  9.52381     32     16
#  111       25  9.52381    -16     16
#  1191      25  9.52381    -32     16
#  10975     35  9.52381     32     16
#  675       25  9.52381    -16     16
#  8518      35  9.52381     32     16
#
#  [3600 rows x 13 columns], array([ 15.,  15.,  15., ...,  25.,  25.,  15.]))

# %%
## using Ridge

clf_rdg = RidgeClassifier(alpha=1).fit(trainX,trainY)
pred_rdg = clf_rdg.predict(testX)
print precision_score(testY, pred_rdg, average='micro')  
print recall_score(testY, pred_rdg, average='micro')
confusion_matrix(testY, pred_rdg)
# Out:
# 0.955555555556
# 0.955555555556
# array([[214,   0,   0,   0],
#        [  0, 104,   0,   0],
#        [  0,   2,  23,   0],
#        [  3,  11,   0,   3]])

# %%
## using Lasso

clf_las = Lasso(alpha=1).fit(trainX,trainY)
pred_las = clf_las.predict(testX)
print precision_score(testY, pred_las, average='micro')  
print recall_score(testY, pred_las, average='micro')
confusion_matrix(testY, pred_las)

# %%
## using RF

clf_rf = RandomForestClassifier(n_estimators=100, max_depth=10)
clf_rf.fit(trainX, trainY)
pred_rf = clf_rf.predict(testX)
print precision_score(testY, pred_rf, average='micro')  
print recall_score(testY, pred_rf, average='micro')
confusion_matrix(testY, pred_rf)
# Out:
# 1.0
# 1.0
# array([[214,   0,   0,   0],
#        [  0, 104,   0,   0],
#        [  0,   0,  25,   0],
#        [  0,   0,   0,  17]])

# %%
## using GBDT

clf_gb = GradientBoostingClassifier(n_estimators=100, max_depth=3)
clf_gb.fit(trainX, trainY)
pred_gb = clf_gb.predict(testX)
print precision_score(testY, pred_gb, average='micro')  
print recall_score(testY, pred_gb, average='micro')
confusion_matrix(testY, pred_gb)
# Out:
# 1.0
# 1.0
# array([[2222,    0,    0,    0],
#        [   0, 1111,    0,    0],
#        [   0,    0,  186,    0],
#        [   0,    0,    0,   81]])

# %%
# neural network
def fit_predict_NN(trainX, trainY, testX, activate_functions, hidden_layers):
    X_ = theano.shared(trainX, name='X')
    y_ = theano.shared(trainY, name='y')
    param = T.vector()
    dim = X.shape[1]
    
    def activation(data_, parameter):
        n_previous = 0
        dim_previous = dim
        h = data_
        for n_hidden, func in zip(hidden_layers, activate_functions):
            N = dim_previous * n_hidden
            W_ = parameter[n_previous:n_previous + N].reshape((dim_previous, n_hidden))
            h = func(h.dot(W_))
            dim_previous = n_hidden
            n_previous += N

        # output     
        v_ = parameter[n_previous:]
        output = h.dot(v_)
        n_previous = n_previous + dim_previous
        
        return T.nnet.sigmoid(output), n_previous

    p_sig = activation(X_, param)[0]
    p_bck = 1 - p_sig
    llh_ = y_.dot(T.log(p_sig)) + (1 - y_).dot(T.log(p_bck))
    loss = -llh_
    
    # optimize
    loss_function = theano.function([param], loss)
    loss_grad = theano.function([param], theano.grad(loss, param))
    result = minimize(loss_function, jac=loss_grad, x0=numpy.random.normal(size=activation(X_, param)[1]))
    optimal_params = result['x']
    
    # predict data
    data = T.matrix()
    compiled_activation = theano.function([data, param], activation(data, param)[0])
    
    return compiled_activation(testX, optimal_params)

# %%
## define activation function
#sigmoid (which we used, T.nnet.sigmoid)
#leaky ReLU (defined below)
#softplus (T.nnet.softplus)

def LeakyReLU(x):
    return T.switch(x > 0, x, 0.5 * x)

# %%
pred = fit_predict_NN(trainX, trainY, testX, [T.nnet.sigmoid] * 3, [20, 10, 5])
print precision_score(testY, pred, average='micro')  
print recall_score(testY, pred, average='micro')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-2dff3e1fc82a> in <module>()
# ----> 1 pred = fit_predict_NN(trainX, trainY, testX, [T.nnet.sigmoid] * 3, [20, 10, 5])
#       2 print precision_score(testY, pred_gb, average='micro')
#       3 print recall_score(testY, pred_gb, average='micro')
#
# <ipython-input-20-3d2c600e86ba> in fit_predict_NN(trainX, trainY, testX, activate_functions, hidden_layers)
#      24         return T.nnet.sigmoid(output), n_previous
#      25
# ---> 26     p_sig = activation(X_, param)[0]
#      27     p_bck = 1 - p_sig
#      28     llh_ = y_.dot(T.log(p_sig)) + (1 - y_).dot(T.log(p_bck))
#
# <ipython-input-20-3d2c600e86ba> in activation(data_, parameter)
#      13             N = dim_previous * n_hidden
#      14             W_ = parameter[n_previous:n_previous + N].reshape((dim_previous, n_hidden))
# ---> 15             h = func(h.dot(W_))
#      16             dim_previous = n_hidden
#      17             n_previous += N
#
# AttributeError: 'SharedVariable' object has no attribute 'dot'

# %%
import numpy as np
import time
import theano
A = np.random.rand(1000,10000).astype(theano.config.floatX)
B = np.random.rand(10000,1000).astype(theano.config.floatX)
np_start = time.time()
AB = A.dot(B)
np_end = time.time()
X,Y = theano.tensor.matrices('XY')
mf = theano.function([X,Y],X.dot(Y))
t_start = time.time()
tAB = mf(A,B)
t_end = time.time()
print("NP time: %f[s], theano time: %f[s] (times should be close when run on CPU!)" %(
                                           np_end-np_start, t_end-t_start))
print("Result difference: %f" % (np.abs(AB-tAB).max(), ))
# Out:
# WARNING (theano.gof.compilelock): Overriding existing lock by dead process '7896' (I am process '1000')
# WARNING:theano.gof.compilelock:Overriding existing lock by dead process '7896' (I am process '1000')
# ===============================
# ===============================
# C:/TDM-GCC-64/bin/../lib/gcc/x86_64-w64-mingw32/5.1.0/libblas.a(xerbla.o):xerbla.f:(.text+0x55): undefined reference to `_gfortran_st_write'
# C:/TDM-GCC-64/bin/../lib/gcc/x86_64-w64-mingw32/5.1.0/libblas.a(xerbla.o):xerbla.f:(.text+0x5f): undefined reference to `_gfortran_string_len_trim'
# C:/TDM-GCC-64/bin/../lib/gcc/x86_64-w64-mingw32/5.1.0/libblas.a(xerbla.o):xerbla.f:(.text+0x76): undefined reference to `_gfortran_transfer_character_write'
# C:/TDM-GCC-64/bin/../lib/gcc/x86_64-w64-mingw32/5.1.0/libblas.a(xerbla.o):xerbla.f:(.text+0x87): undefined reference to `_gfortran_transfer_integer_write'
# C:/TDM-GCC-64/bin/../lib/gcc/x86_64-w64-mingw32/5.1.0/libblas.a(xerbla.o):xerbla.f:(.text+0x8f): undefined reference to `_gfortran_st_write_done'
# C:/TDM-GCC-64/bin/../lib/gcc/x86_64-w64-mingw32/5.1.0/libblas.a(xerbla.o):xerbla.f:(.text+0x98): undefined reference to `_gfortran_stop_string'
# collect2.exe: error: ld returned 1 exit status
# 00001	#include <Python.h>
# 00002	#include <iostream>
# 00003	#include "theano_mod_helper.h"
# 00004	#include <math.h>
# 00005	#include <numpy/arrayobject.h>
# 00006	#include <numpy/arrayscalars.h>
# 00007	#include <iostream>
# 00008	#include <time.h>
# 00009	#include <sys/time.h>
# 00010	//////////////////////
# 00011	////  Support Code
# 00012	//////////////////////
# 00013
# 00014
# 00015	    extern "C"
# 00016	    {
# 00017
# 00018	        void xerbla_(char*, void *);
# 00019
# 00020	    /***********/
# 00021	    /* Level 1 */
# 00022	    /***********/
# 00023
# 00024	    /* Single Precision */
# 00025
# 00026	        void srot_(const int*, float *, const int*, float *, const int*, const float *, const float *);
# 00027	        void srotg_(float *,float *,float *,float *);
# 00028	        void srotm_( const int*, float *, const int*, float *, const int*, const float *);
# 00029	        void srotmg_(float *,float *,float *,const float *, float *);
# 00030	        void sswap_( const int*, float *, const int*, float *, const int*);
# 00031	        void scopy_( const int*, const float *, const int*, float *, const int*);
# 00032	        void saxpy_( const int*, const float *, const float *, const int*, float *, const int*);
# 00033	        float sdot_(const int*, const float *, const int*, const float *, const int*);
# 00034	        void sdot_sub_(const int*, const float *, const int*, const float *, const int*, float *);
# 00035	        void sdsdot_sub_( const int*, const float *, const float *, const int*, const float *, const int*, float *);
# 00036	        void sscal_( const int*, const float *, float *, const int*);
# 00037	        void snrm2_sub_( const int*, const float *, const int*, float *);
# 00038	        void sasum_sub_( const int*, const float *, const int*, float *);
# 00039	        void isamax_sub_( const int*, const float * , const int*, const int*);
# 00040
# 00041	    /* Double Precision */
# 00042
# 00043	        void drot_(const int*, double *, const int*, double *, const int*, const double *, const double *);
# 00044	        void drotg_(double *,double *,double *,double *);
# 00045	        void drotm_( const int*, double *, const int*, double *, const int*, const double *);
# 00046	        void drotmg_(double *,double *,double *,const double *, double *);
# 00047	        void dswap_( const int*, double *, const int*, double *, const int*);
# 00048	        void dcopy_( const int*, const double *, const int*, double *, const int*);
# 00049	        void daxpy_( const int*, const double *, const double *, const int*, double *, const int*);
# 00050	        void dswap_( const int*, double *, const int*, double *, const int*);
# 00051	        double ddot_(const int*, const double *, const int*, const double *, const int*);
# 00052	        void dsdot_sub_(const int*, const float *, const int*, const float *, const int*, double *);
# 00053	        void ddot_sub_( const int*, const double *, const int*, const double *, const int*, double *);
# 00054	        void dscal_( const int*, const double *, double *, const int*);
# 00055	        void dnrm2_sub_( const int*, const double *, const int*, double *);
# 00056	        void dasum_sub_( const int*, const double *, const int*, double *);
# 00057	        void idamax_sub_( const int*, const double * , const int*, const int*);
# 00058
# 00059	    /* Single Complex Precision */
# 00060
# 00061	        void cswap_( const int*, void *, const int*, void *, const int*);
# 00062	        void ccopy_( const int*, const void *, const int*, void *, const int*);
# 00063	        void caxpy_( const int*, const void *, const void *, const int*, void *, const int*);
# 00064	        void cswap_( const int*, void *, const int*, void *, const int*);
# 00065	        void cdotc_sub_( const int*, const void *, const int*, const void *, const int*, void *);
# 00066	        void cdotu_sub_( const int*, const void *, const int*, const void *, const int*, void *);
# 00067	        void cscal_( const int*, const void *, void *, const int*);
# 00068	        void icamax_sub_( const int*, const void *, const int*, const int*);
# 00069	        void csscal_( const int*, const float *, void *, const int*);
# 00070	        void scnrm2_sub_( const int*, const void *, const int*, float *);
# 00071	        void scasum_sub_( const int*, const void *, const int*, float *);
# 00072
# 00073	    /* Double Complex Precision */
# 00074
# 00075	        void zswap_( const int*, void *, const int*, void *, const int*);
# 00076	        void zcopy_( const int*, const void *, const int*, void *, const int*);
# 00077	        void zaxpy_( const int*, const void *, const void *, const int*, void *, const int*);
# 00078	        void zswap_( const int*, void *, const int*, void *, const int*);
# 00079	        void zdotc_sub_( const int*, const void *, const int*, const void *, const int*, void *);
# 00080	        void zdotu_sub_( const int*, const void *, const int*, const void *, const int*, void *);
# 00081	        void zdscal_( const int*, const double *, void *, const int*);
# 00082	        void zscal_( const int*, const void *, void *, const int*);
# 00083	        void dznrm2_sub_( const int*, const void *, const int*, double *);
# 00084	        void dzasum_sub_( const int*, const void *, const int*, double *);
# 00085	        void izamax_sub_( const int*, const void *, const int*, const int*);
# 00086
# 00087	    /***********/
# 00088	    /* Level 2 */
# 00089	    /***********/
# 00090
# 00091	    /* Single Precision */
# 00092
# 00093	        void sgemv_(char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00094	        void sgbmv_(char*, const int*, const int*, const int*, const int*, const float *,  const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00095	        void ssymv_(char*, const int*, const float *, const float *, const int*, const float *,  const int*, const float *, float *, const int*);
# 00096	        void ssbmv_(char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00097	        void sspmv_(char*, const int*, const float *, const float *, const float *, const int*, const float *, float *, const int*);
# 00098	        void strmv_( char*, char*, char*, const int*, const float *, const int*, float *, const int*);
# 00099	        void stbmv_( char*, char*, char*, const int*, const int*, const float *, const int*, float *, const int*);
# 00100	        void strsv_( char*, char*, char*, const int*, const float *, const int*, float *, const int*);
# 00101	        void stbsv_( char*, char*, char*, const int*, const int*, const float *, const int*, float *, const int*);
# 00102	        void stpmv_( char*, char*, char*, const int*, const float *, float *, const int*);
# 00103	        void stpsv_( char*, char*, char*, const int*, const float *, float *, const int*);
# 00104	        void sger_( const int*, const int*, const float *, const float *, const int*, const float *, const int*, float *, const int*);
# 00105	        void ssyr_(char*, const int*, const float *, const float *, const int*, float *, const int*);
# 00106	        void sspr_(char*, const int*, const float *, const float *, const int*, float *);
# 00107	        void sspr2_(char*, const int*, const float *, const float *, const int*, const float *, const int*,  float *);
# 00108	        void ssyr2_(char*, const int*, const float *, const float *, const int*, const float *, const int*,  float *, const int*);
# 00109
# 00110	    /* Double Precision */
# 00111
# 00112	        void dgemv_(char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00113	        void dgbmv_(char*, const int*, const int*, const int*, const int*, const double *,  const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00114	        void dsymv_(char*, const int*, const double *, const double *, const int*, const double *,  const int*, const double *, double *, const int*);
# 00115	        void dsbmv_(char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00116	        void dspmv_(char*, const int*, const double *, const double *, const double *, const int*, const double *, double *, const int*);
# 00117	        void dtrmv_( char*, char*, char*, const int*, const double *, const int*, double *, const int*);
# 00118	        void dtbmv_( char*, char*, char*, const int*, const int*, const double *, const int*, double *, const int*);
# 00119	        void dtrsv_( char*, char*, char*, const int*, const double *, const int*, double *, const int*);
# 00120	        void dtbsv_( char*, char*, char*, const int*, const int*, const double *, const int*, double *, const int*);
# 00121	        void dtpmv_( char*, char*, char*, const int*, const double *, double *, const int*);
# 00122	        void dtpsv_( char*, char*, char*, const int*, const double *, double *, const int*);
# 00123	        void dger_( const int*, const int*, const double *, const double *, const int*, const double *, const int*, double *, const int*);
# 00124	        void dsyr_(char*, const int*, const double *, const double *, const int*, double *, const int*);
# 00125	        void dspr_(char*, const int*, const double *, const double *, const int*, double *);
# 00126	        void dspr2_(char*, const int*, const double *, const double *, const int*, const double *, const int*,  double *);
# 00127	        void dsyr2_(char*, const int*, const double *, const double *, const int*, const double *, const int*,  double *, const int*);
# 00128
# 00129	    /* Single Complex Precision */
# 00130
# 00131	        void cgemv_(char*, const int*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00132	        void cgbmv_(char*, const int*, const int*, const int*, const int*, const void *,  const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00133	        void chemv_(char*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00134	        void chbmv_(char*, const int*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00135	        void chpmv_(char*, const int*, const void *, const void *, const void *, const int*, const void *, void *, const int*);
# 00136	        void ctrmv_( char*, char*, char*, const int*, const void *, const int*, void *, const int*);
# 00137	        void ctbmv_( char*, char*, char*, const int*, const int*, const void *, const int*, void *, const int*);
# 00138	        void ctpmv_( char*, char*, char*, const int*, const void *, void *, const int*);
# 00139	        void ctrsv_( char*, char*, char*, const int*, const void *, const int*, void *, const int*);
# 00140	        void ctbsv_( char*, char*, char*, const int*, const int*, const void *, const int*, void *, const int*);
# 00141	        void ctpsv_( char*, char*, char*, const int*, const void *, void *,const int*);
# 00142	        void cgerc_( const int*, const int*, const void *, const void *, const int*, const void *, const int*, void *, const int*);
# 00143	        void cgeru_( const int*, const int*, const void *, const void *, const int*, const void *, const int*, void *,  const int*);
# 00144	        void cher_(char*, const int*, const float *, const void *, const int*, void *, const int*);
# 00145	        void cher2_(char*, const int*, const void *, const void *, const int*, const void *, const int*, void *, const int*);
# 00146	        void chpr_(char*, const int*, const float *, const void *, const int*, void *);
# 00147	        void chpr2_(char*, const int*, const float *, const void *, const int*, const void *, const int*, void *);
# 00148
# 00149	    /* Double Complex Precision */
# 00150
# 00151	        void zgemv_(char*, const int*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00152	        void zgbmv_(char*, const int*, const int*, const int*, const int*, const void *,  const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00153	        void zhemv_(char*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00154	        void zhbmv_(char*, const int*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00155	        void zhpmv_(char*, const int*, const void *, const void *, const void *, const int*, const void *, void *, const int*);
# 00156	        void ztrmv_( char*, char*, char*, const int*, const void *, const int*, void *, const int*);
# 00157	        void ztbmv_( char*, char*, char*, const int*, const int*, const void *, const int*, void *, const int*);
# 00158	        void ztpmv_( char*, char*, char*, const int*, const void *, void *, const int*);
# 00159	        void ztrsv_( char*, char*, char*, const int*, const void *, const int*, void *, const int*);
# 00160	        void ztbsv_( char*, char*, char*, const int*, const int*, const void *, const int*, void *, const int*);
# 00161	        void ztpsv_( char*, char*, char*, const int*, const void *, void *,const int*);
# 00162	        void zgerc_( const int*, const int*, const void *, const void *, const int*, const void *, const int*, void *, const int*);
# 00163	        void zgeru_( const int*, const int*, const void *, const void *, const int*, const void *, const int*, void *,  const int*);
# 00164	        void zher_(char*, const int*, const double *, const void *, const int*, void *, const int*);
# 00165	        void zher2_(char*, const int*, const void *, const void *, const int*, const void *, const int*, void *, const int*);
# 00166	        void zhpr_(char*, const int*, const double *, const void *, const int*, void *);
# 00167	        void zhpr2_(char*, const int*, const double *, const void *, const int*, const void *, const int*, void *);
# 00168
# 00169	    /***********/
# 00170	    /* Level 3 */
# 00171	    /***********/
# 00172
# 00173	    /* Single Precision */
# 00174
# 00175	        void sgemm_(char*, char*, const int*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00176	        void ssymm_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00177	        void ssyrk_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, float *, const int*);
# 00178	        void ssyr2k_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00179	        void strmm_(char*, char*, char*, char*, const int*, const int*, const float *, const float *, const int*, float *, const int*);
# 00180	        void strsm_(char*, char*, char*, char*, const int*, const int*, const float *, const float *, const int*, float *, const int*);
# 00181
# 00182	    /* Double Precision */
# 00183
# 00184	        void dgemm_(char*, char*, const int*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00185	        void dsymm_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00186	        void dsyrk_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, double *, const int*);
# 00187	        void dsyr2k_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00188	        void dtrmm_(char*, char*, char*, char*, const int*, const int*, const double *, const double *, const int*, double *, const int*);
# 00189	        void dtrsm_(char*, char*, char*, char*, const int*, const int*, const double *, const double *, const int*, double *, const int*);
# 00190
# 00191	    /* Single Complex Precision */
# 00192
# 00193	        void cgemm_(char*, char*, const int*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00194	        void csymm_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00195	        void chemm_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00196	        void csyrk_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, float *, const int*);
# 00197	        void cherk_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, float *, const int*);
# 00198	        void csyr2k_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00199	        void cher2k_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00200	        void ctrmm_(char*, char*, char*, char*, const int*, const int*, const float *, const float *, const int*, float *, const int*);
# 00201	        void ctrsm_(char*, char*, char*, char*, const int*, const int*, const float *, const float *, const int*, float *, const int*);
# 00202
# 00203	    /* Double Complex Precision */
# 00204
# 00205	        void zgemm_(char*, char*, const int*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00206	        void zsymm_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00207	        void zhemm_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00208	        void zsyrk_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, double *, const int*);
# 00209	        void zherk_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, double *, const int*);
# 00210	        void zsyr2k_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00211	        void zher2k_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00212	        void ztrmm_(char*, char*, char*, char*, const int*, const int*, const double *, const double *, const int*, double *, const int*);
# 00213	        void ztrsm_(char*, char*, char*, char*, const int*, const int*, const double *, const double *, const int*, double *, const int*);
# 00214
# 00215	    }
# 00216
# 00217	        #ifndef MOD
# 00218	        #define MOD %
# 00219	        #endif
# 00220	        static double time_time() // a time function like time.time()
# 00221	        {
# 00222	            struct timeval tv;
# 00223	            gettimeofday(&tv, 0);
# 00224	            return (double) tv.tv_sec + (double) tv.tv_usec / 1000000.0;
# 00225	        }
# 00226
# 00227
# 00228	    namespace {
# 00229	    struct __struct_compiled_op_d794461d8649d656d8a368a82107fbc7 {
# 00230	        PyObject* __ERROR;
# 00231
# 00232	        PyObject* storage_V3;
# 00233	PyObject* storage_V5;
# 00234	PyObject* storage_V1;
# 00235
# 00236
# 00237	        __struct_compiled_op_d794461d8649d656d8a368a82107fbc7() {
# 00238	            // This is only somewhat safe because we:
# 00239	            //  1) Are not a virtual class
# 00240	            //  2) Do not use any virtual classes in the members
# 00241	            //  3) Deal with mostly POD and pointers
# 00242
# 00243	            // If this changes, we would have to revise this, but for
# 00244	            // now I am tired of chasing segfaults because
# 00245	            // initialization code had an error and some pointer has
# 00246	            // a junk value.
# 00247	            memset(this, 0, sizeof(*this));
# 00248	        }
# 00249	        ~__struct_compiled_op_d794461d8649d656d8a368a82107fbc7(void) {
# 00250	            cleanup();
# 00251	        }
# 00252
# 00253	        int init(PyObject* __ERROR, PyObject* storage_V3, PyObject* storage_V5, PyObject* storage_V1) {
# 00254	            Py_XINCREF(storage_V3);
# 00255	Py_XINCREF(storage_V5);
# 00256	Py_XINCREF(storage_V1);
# 00257	            this->storage_V3 = storage_V3;
# 00258	this->storage_V5 = storage_V5;
# 00259	this->storage_V1 = storage_V1;
# 00260
# 00261
# 00262
# 00263
# 00264
# 00265	            this->__ERROR = __ERROR;
# 00266	            return 0;
# 00267	        }
# 00268	        void cleanup(void) {
# 00269	            __label_1:
# 00270
# 00271	double __DUMMY_1;
# 00272	__label_3:
# 00273
# 00274	double __DUMMY_3;
# 00275	__label_5:
# 00276
# 00277	double __DUMMY_5;
# 00278	__label_8:
# 00279
# 00280	double __DUMMY_8;
# 00281
# 00282	            Py_XDECREF(this->storage_V3);
# 00283	Py_XDECREF(this->storage_V5);
# 00284	Py_XDECREF(this->storage_V1);
# 00285	        }
# 00286	        int run(void) {
# 00287	            int __failure = 0;
# 00288
# 00289	    PyObject* py_V1;
# 00290
# 00291	        PyArrayObject* V1;
# 00292
# 00293	            typedef npy_float64 dtype_V1;
# 00294
# 00295	    PyObject* py_V3;
# 00296
# 00297	        PyArrayObject* V3;
# 00298
# 00299	            typedef npy_float64 dtype_V3;
# 00300
# 00301	    PyObject* py_V5;
# 00302
# 00303	        PyArrayObject* V5;
# 00304
# 00305	            typedef npy_float64 dtype_V5;
# 00306
# 00307	{
# 00308
# 00309	    py_V1 = Py_None;
# 00310	    {Py_XINCREF(py_V1);}
# 00311
# 00312	        V1 = NULL;
# 00313
# 00314	{
# 00315
# 00316	    py_V3 = PyList_GET_ITEM(storage_V3, 0);
# 00317	    {Py_XINCREF(py_V3);}
# 00318
# 00319	            V3 = NULL;
# 00320	            if (py_V3 == Py_None) {
# 00321	                // We can either fail here or set V3 to NULL and rely on Ops
# 00322	                // using tensors to handle the NULL case, but if they fail to do so
# 00323	                // they'll end up with nasty segfaults, so this is public service.
# 00324	                PyErr_SetString(PyExc_ValueError, "expected an ndarray, not None");
# 00325	                {
# 00326	        __failure = 4;
# 00327	        if (!PyErr_Occurred()) {
# 00328	            PyErr_SetString(PyExc_RuntimeError,
# 00329	                "Unexpected error in an Op's C code. "
# 00330	                "No Python exception was set.");
# 00331	            }
# 00332	        goto __label_4;}
# 00333	            }
# 00334	            if (!PyArray_Check(py_V3)) {
# 00335	                PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 00336	                {
# 00337	        __failure = 4;
# 00338	        if (!PyErr_Occurred()) {
# 00339	            PyErr_SetString(PyExc_RuntimeError,
# 00340	                "Unexpected error in an Op's C code. "
# 00341	                "No Python exception was set.");
# 00342	            }
# 00343	        goto __label_4;}
# 00344	            }
# 00345	            // We expect NPY_FLOAT64
# 00346	            if (!PyArray_ISALIGNED((PyArrayObject*) py_V3)) {
# 00347	                PyArrayObject * tmp = (PyArrayObject*) py_V3;
# 00348	                PyErr_Format(PyExc_NotImplementedError,
# 00349	                             "expected an aligned array of type %ld "
# 00350	                             "(NPY_FLOAT64), got non-aligned array of type %ld"
# 00351	                             " with %ld dimensions, with 3 last dims "
# 00352	                             "%ld, %ld, %ld"
# 00353	                             " and 3 last strides %ld %ld, %ld.",
# 00354	                             (long int) NPY_FLOAT64,
# 00355	                             (long int) PyArray_TYPE((PyArrayObject*) py_V3),
# 00356	                             (long int) PyArray_NDIM(tmp),
# 00357	                             (long int) PyArray_NDIM(tmp) >= 3 ?
# 00358	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00359	                             (long int) PyArray_NDIM(tmp) >= 2 ?
# 00360	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00361	                             (long int) PyArray_NDIM(tmp) >= 1 ?
# 00362	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-1] : -1,
# 00363	                             (long int) PyArray_NDIM(tmp) >= 3 ?
# 00364	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00365	                             (long int) PyArray_NDIM(tmp) >= 2 ?
# 00366	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00367	                             (long int) PyArray_NDIM(tmp) >= 1 ?
# 00368	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-1] : -1
# 00369	            );
# 00370	                {
# 00371	        __failure = 4;
# 00372	        if (!PyErr_Occurred()) {
# 00373	            PyErr_SetString(PyExc_RuntimeError,
# 00374	                "Unexpected error in an Op's C code. "
# 00375	                "No Python exception was set.");
# 00376	            }
# 00377	        goto __label_4;}
# 00378	            }
# 00379	            // This is a TypeError to be consistent with DEBUG_MODE
# 00380	            // Note: DEBUG_MODE also tells the name of the container
# 00381	            if (PyArray_TYPE((PyArrayObject*) py_V3) != NPY_FLOAT64) {
# 00382	                PyErr_Format(PyExc_TypeError,
# 00383	                             "expected type_num %d (NPY_FLOAT64) got %d",
# 00384	                             NPY_FLOAT64, PyArray_TYPE((PyArrayObject*) py_V3));
# 00385	                {
# 00386	        __failure = 4;
# 00387	        if (!PyErr_Occurred()) {
# 00388	            PyErr_SetString(PyExc_RuntimeError,
# 00389	                "Unexpected error in an Op's C code. "
# 00390	                "No Python exception was set.");
# 00391	            }
# 00392	        goto __label_4;}
# 00393	            }
# 00394
# 00395	        V3 = (PyArrayObject*)(py_V3);
# 00396	        Py_XINCREF(V3);
# 00397
# 00398	{
# 00399
# 00400	    py_V5 = PyList_GET_ITEM(storage_V5, 0);
# 00401	    {Py_XINCREF(py_V5);}
# 00402
# 00403	            V5 = NULL;
# 00404	            if (py_V5 == Py_None) {
# 00405	                // We can either fail here or set V5 to NULL and rely on Ops
# 00406	                // using tensors to handle the NULL case, but if they fail to do so
# 00407	                // they'll end up with nasty segfaults, so this is public service.
# 00408	                PyErr_SetString(PyExc_ValueError, "expected an ndarray, not None");
# 00409	                {
# 00410	        __failure = 6;
# 00411	        if (!PyErr_Occurred()) {
# 00412	            PyErr_SetString(PyExc_RuntimeError,
# 00413	                "Unexpected error in an Op's C code. "
# 00414	                "No Python exception was set.");
# 00415	            }
# 00416	        goto __label_6;}
# 00417	            }
# 00418	            if (!PyArray_Check(py_V5)) {
# 00419	                PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 00420	                {
# 00421	        __failure = 6;
# 00422	        if (!PyErr_Occurred()) {
# 00423	            PyErr_SetString(PyExc_RuntimeError,
# 00424	                "Unexpected error in an Op's C code. "
# 00425	                "No Python exception was set.");
# 00426	            }
# 00427	        goto __label_6;}
# 00428	            }
# 00429	            // We expect NPY_FLOAT64
# 00430	            if (!PyArray_ISALIGNED((PyArrayObject*) py_V5)) {
# 00431	                PyArrayObject * tmp = (PyArrayObject*) py_V5;
# 00432	                PyErr_Format(PyExc_NotImplementedError,
# 00433	                             "expected an aligned array of type %ld "
# 00434	                             "(NPY_FLOAT64), got non-aligned array of type %ld"
# 00435	                             " with %ld dimensions, with 3 last dims "
# 00436	                             "%ld, %ld, %ld"
# 00437	                             " and 3 last strides %ld %ld, %ld.",
# 00438	                             (long int) NPY_FLOAT64,
# 00439	                             (long int) PyArray_TYPE((PyArrayObject*) py_V5),
# 00440	                             (long int) PyArray_NDIM(tmp),
# 00441	                             (long int) PyArray_NDIM(tmp) >= 3 ?
# 00442	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00443	                             (long int) PyArray_NDIM(tmp) >= 2 ?
# 00444	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00445	                             (long int) PyArray_NDIM(tmp) >= 1 ?
# 00446	            PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-1] : -1,
# 00447	                             (long int) PyArray_NDIM(tmp) >= 3 ?
# 00448	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00449	                             (long int) PyArray_NDIM(tmp) >= 2 ?
# 00450	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00451	                             (long int) PyArray_NDIM(tmp) >= 1 ?
# 00452	            PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-1] : -1
# 00453	            );
# 00454	                {
# 00455	        __failure = 6;
# 00456	        if (!PyErr_Occurred()) {
# 00457	            PyErr_SetString(PyExc_RuntimeError,
# 00458	                "Unexpected error in an Op's C code. "
# 00459	                "No Python exception was set.");
# 00460	            }
# 00461	        goto __label_6;}
# 00462	            }
# 00463	            // This is a TypeError to be consistent with DEBUG_MODE
# 00464	            // Note: DEBUG_MODE also tells the name of the container
# 00465	            if (PyArray_TYPE((PyArrayObject*) py_V5) != NPY_FLOAT64) {
# 00466	                PyErr_Format(PyExc_TypeError,
# 00467	                             "expected type_num %d (NPY_FLOAT64) got %d",
# 00468	                             NPY_FLOAT64, PyArray_TYPE((PyArrayObject*) py_V5));
# 00469	                {
# 00470	        __failure = 6;
# 00471	        if (!PyErr_Occurred()) {
# 00472	            PyErr_SetString(PyExc_RuntimeError,
# 00473	                "Unexpected error in an Op's C code. "
# 00474	                "No Python exception was set.");
# 00475	            }
# 00476	        goto __label_6;}
# 00477	            }
# 00478
# 00479	        V5 = (PyArrayObject*)(py_V5);
# 00480	        Py_XINCREF(V5);
# 00481
# 00482	{
# 00483	// Op class Dot22
# 00484
# 00485	        int unit = 0;
# 00486
# 00487	        int type_num = PyArray_DESCR(V3)->type_num;
# 00488	        int type_size = PyArray_DESCR(V3)->elsize; // in bytes
# 00489
# 00490	        npy_intp* Nx = PyArray_DIMS(V3);
# 00491	        npy_intp* Ny = PyArray_DIMS(V5);
# 00492	        npy_intp* Nz = 0; //PyArray_DIMS(V1);
# 00493
# 00494	        npy_intp* Sx = PyArray_STRIDES(V3);
# 00495	        npy_intp* Sy = PyArray_STRIDES(V5);
# 00496	        npy_intp* Sz = 0; //PyArray_STRIDES(V1);
# 00497
# 00498	        //strides for x, y, z in dimensions 0, 1
# 00499	        int sx_0, sx_1, sy_0, sy_1, sz_0, sz_1;
# 00500
# 00501	        if (PyArray_NDIM(V3) != 2) {
# 00502	            PyErr_Format(PyExc_NotImplementedError,
# 00503	                         "rank(x) != 2. rank(x) is %d.",
# 00504	                         PyArray_NDIM(V3));
# 00505	            {
# 00506	        __failure = 7;
# 00507	        if (!PyErr_Occurred()) {
# 00508	            PyErr_SetString(PyExc_RuntimeError,
# 00509	                "Unexpected error in an Op's C code. "
# 00510	                "No Python exception was set.");
# 00511	            }
# 00512	        goto __label_7;};
# 00513	        }
# 00514	        if (PyArray_NDIM(V5) != 2) {
# 00515	            PyErr_Format(PyExc_NotImplementedError,
# 00516	                         "rank(y) != 2. rank(y) is %d.", PyArray_NDIM(V5));
# 00517	            {
# 00518	        __failure = 7;
# 00519	        if (!PyErr_Occurred()) {
# 00520	            PyErr_SetString(PyExc_RuntimeError,
# 00521	                "Unexpected error in an Op's C code. "
# 00522	                "No Python exception was set.");
# 00523	            }
# 00524	        goto __label_7;};
# 00525	        }
# 00526	        if (V1 && PyArray_NDIM(V1) != 2) {
# 00527	            PyErr_Format(PyExc_NotImplementedError,
# 00528	                         "rank(z) != 2. rank(z) is %d.", PyArray_NDIM(V1));
# 00529	            {
# 00530	        __failure = 7;
# 00531	        if (!PyErr_Occurred()) {
# 00532	            PyErr_SetString(PyExc_RuntimeError,
# 00533	                "Unexpected error in an Op's C code. "
# 00534	                "No Python exception was set.");
# 00535	            }
# 00536	        goto __label_7;};
# 00537	        }
# 00538
# 00539	        if ((NULL == V1)
# 00540	            || (PyArray_DIMS(V1)[0] != PyArray_DIMS(V3)[0])
# 00541	            || (PyArray_DIMS(V1)[1] != PyArray_DIMS(V5)[1]))
# 00542	        {
# 00543	            if (NULL != V1) Py_XDECREF(V1);
# 00544	            npy_intp dims[2];
# 00545	            dims[0] = PyArray_DIMS(V3)[0];
# 00546	            dims[1] = PyArray_DIMS(V5)[1];
# 00547	            V1 = (PyArrayObject*)PyArray_SimpleNew(2, dims,
# 00548	                            PyArray_TYPE(V3));
# 00549	            //fprintf(stderr, "Dot Allocating %i %i\n", dims[0], dims[1]);
# 00550	            if(!V1) {
# 00551	                PyErr_SetString(PyExc_MemoryError,
# 00552	                                "failed to alloc dot22 output");
# 00553	                {
# 00554	        __failure = 7;
# 00555	        if (!PyErr_Occurred()) {
# 00556	            PyErr_SetString(PyExc_RuntimeError,
# 00557	                "Unexpected error in an Op's C code. "
# 00558	                "No Python exception was set.");
# 00559	            }
# 00560	        goto __label_7;}
# 00561	            }
# 00562	        }
# 00563	        Nz = PyArray_DIMS(V1);
# 00564	        Sz = PyArray_STRIDES(V1);
# 00565
# 00566
# 00567	        if ((PyArray_DESCR(V3)->type_num != NPY_DOUBLE)
# 00568	            && (PyArray_DESCR(V3)->type_num != NPY_FLOAT))
# 00569	        {PyErr_SetString(PyExc_NotImplementedError, "type(x) is not double or float"); {
# 00570	        __failure = 7;
# 00571	        if (!PyErr_Occurred()) {
# 00572	            PyErr_SetString(PyExc_RuntimeError,
# 00573	                "Unexpected error in an Op's C code. "
# 00574	                "No Python exception was set.");
# 00575	            }
# 00576	        goto __label_7;};}
# 00577
# 00578	        if ((PyArray_DESCR(V5)->type_num != NPY_DOUBLE)
# 00579	            && (PyArray_DESCR(V5)->type_num != NPY_FLOAT))
# 00580	        {PyErr_SetString(PyExc_NotImplementedError, "type(y) is not double or float"); {
# 00581	        __failure = 7;
# 00582	        if (!PyErr_Occurred()) {
# 00583	            PyErr_SetString(PyExc_RuntimeError,
# 00584	                "Unexpected error in an Op's C code. "
# 00585	                "No Python exception was set.");
# 00586	            }
# 00587	        goto __label_7;};}
# 00588
# 00589	        if ((PyArray_DESCR(V1)->type_num != NPY_DOUBLE)
# 00590	            && (PyArray_DESCR(V1)->type_num != NPY_FLOAT))
# 00591	        {PyErr_SetString(PyExc_NotImplementedError, "type(z) is not double or float"); {
# 00592	        __failure = 7;
# 00593	        if (!PyErr_Occurred()) {
# 00594	            PyErr_SetString(PyExc_RuntimeError,
# 00595	                "Unexpected error in an Op's C code. "
# 00596	                "No Python exception was set.");
# 00597	            }
# 00598	        goto __label_7;};}
# 00599
# 00600	        if ((PyArray_DESCR(V3)->type_num != PyArray_DESCR(V5)->type_num)
# 00601	            ||(PyArray_DESCR(V3)->type_num != PyArray_DESCR(V1)->type_num))
# 00602	        { PyErr_SetString(PyExc_NotImplementedError, "type(x), type(y), type(z) are not all the same"); {
# 00603	        __failure = 7;
# 00604	        if (!PyErr_Occurred()) {
# 00605	            PyErr_SetString(PyExc_RuntimeError,
# 00606	                "Unexpected error in an Op's C code. "
# 00607	                "No Python exception was set.");
# 00608	            }
# 00609	        goto __label_7;}; }
# 00610
# 00611	        if (Nx[0] != Nz[0])
# 00612	        {
# 00613	            PyErr_Format(PyExc_ValueError,
# 00614	                "Shape mismatch: x has %ld rows but z has %ld rows",
# 00615	                (long int)Nx[0], (long int)Nz[0]);
# 00616	            {
# 00617	        __failure = 7;
# 00618	        if (!PyErr_Occurred()) {
# 00619	            PyErr_SetString(PyExc_RuntimeError,
# 00620	                "Unexpected error in an Op's C code. "
# 00621	                "No Python exception was set.");
# 00622	            }
# 00623	        goto __label_7;};
# 00624	        }
# 00625	        if (Nx[1] != Ny[0])
# 00626	        {
# 00627	            PyErr_Format(PyExc_ValueError,
# 00628	                "Shape mismatch: x has %ld cols (and %ld rows) but y has %ld rows (and %ld cols)",
# 00629	                (long int)Nx[1], (long int)Nx[0], (long int)Ny[0], (long int)Ny[1]);
# 00630	            {
# 00631	        __failure = 7;
# 00632	        if (!PyErr_Occurred()) {
# 00633	            PyErr_SetString(PyExc_RuntimeError,
# 00634	                "Unexpected error in an Op's C code. "
# 00635	                "No Python exception was set.");
# 00636	            }
# 00637	        goto __label_7;};
# 00638	        }
# 00639	        if (Ny[1] != Nz[1])
# 00640	        {
# 00641	            PyErr_Format(PyExc_ValueError,
# 00642	                "Shape mismatch: y has %ld cols but z has %ld cols",
# 00643	                (long int)Ny[1], (long int)Nz[1]);
# 00644	            {
# 00645	        __failure = 7;
# 00646	        if (!PyErr_Occurred()) {
# 00647	            PyErr_SetString(PyExc_RuntimeError,
# 00648	                "Unexpected error in an Op's C code. "
# 00649	                "No Python exception was set.");
# 00650	            }
# 00651	        goto __label_7;};
# 00652	        }
# 00653
# 00654	        // We must not raise an error when Nx[1] == 0. This would disable cases
# 00655	        // that numpy.dot accept.
# 00656
# 00657	        /*
# 00658	        If some matrices are not contiguous on either dimensions,
# 00659	        or have invalid strides, copy their content into a contiguous one
# 00660	        */
# 00661	        if ((Sx[0] < 1) || (Sx[1] < 1) || (Sx[0] MOD type_size) || (Sx[1] MOD type_size)
# 00662	            || ((Sx[0] != type_size) && (Sx[1] != type_size)))
# 00663	        {
# 00664	            PyArrayObject * _x_copy = (PyArrayObject *) PyArray_Copy(V3);
# 00665	            if (!_x_copy)
# 00666	                {
# 00667	        __failure = 7;
# 00668	        if (!PyErr_Occurred()) {
# 00669	            PyErr_SetString(PyExc_RuntimeError,
# 00670	                "Unexpected error in an Op's C code. "
# 00671	                "No Python exception was set.");
# 00672	            }
# 00673	        goto __label_7;}
# 00674	            Py_XDECREF(V3);
# 00675	            V3 = _x_copy;
# 00676	            Sx = PyArray_STRIDES(V3);
# 00677	        }
# 00678
# 00679	        if ((Sy[0] < 1) || (Sy[1] < 1) || (Sy[0] MOD type_size) || (Sy[1] MOD type_size)
# 00680	            || ((Sy[0] != type_size) && (Sy[1] != type_size)))
# 00681	        {
# 00682	            PyArrayObject * _y_copy = (PyArrayObject *) PyArray_Copy(V5);
# 00683	            if (!_y_copy)
# 00684	                {
# 00685	        __failure = 7;
# 00686	        if (!PyErr_Occurred()) {
# 00687	            PyErr_SetString(PyExc_RuntimeError,
# 00688	                "Unexpected error in an Op's C code. "
# 00689	                "No Python exception was set.");
# 00690	            }
# 00691	        goto __label_7;}
# 00692	            Py_XDECREF(V5);
# 00693	            V5 = _y_copy;
# 00694	            Sy = PyArray_STRIDES(V5);
# 00695	        }
# 00696
# 00697	        if ((Sz[0] < 1) || (Sz[1] < 1) || (Sz[0] MOD type_size) || (Sz[1] MOD type_size)
# 00698	            || ((Sz[0] != type_size) && (Sz[1] != type_size)))
# 00699	        {
# 00700	            PyArrayObject * _z_copy = (PyArrayObject *) PyArray_Copy(V1);
# 00701	            if (!_z_copy)
# 00702	                {
# 00703	        __failure = 7;
# 00704	        if (!PyErr_Occurred()) {
# 00705	            PyErr_SetString(PyExc_RuntimeError,
# 00706	                "Unexpected error in an Op's C code. "
# 00707	                "No Python exception was set.");
# 00708	            }
# 00709	        goto __label_7;}
# 00710	            Py_XDECREF(V1);
# 00711	            V1 = _z_copy;
# 00712	            Sz = PyArray_STRIDES(V1);
# 00713	        }
# 00714
# 00715	        /*
# 00716	        encode the stride structure of _x,_y,_zout into a single integer
# 00717	        */
# 00718	        unit |= ((Sx[1] == type_size || Nx[1]==1) ? 0x0 : (Sx[0] == type_size || Nx[0]==1) ? 0x1 : 0x2) << 8;
# 00719	        unit |= ((Sy[1] == type_size || Ny[1]==1) ? 0x0 : (Sy[0] == type_size || Ny[0]==1) ? 0x1 : 0x2) << 4;
# 00720	        unit |= ((Sz[1] == type_size || Nz[1]==1) ? 0x0 : (Sz[0] == type_size || Nz[0]==1) ? 0x1 : 0x2) << 0;
# 00721
# 00722	        /* create appropriate strides for malformed matrices that are row or column
# 00723	         * vectors, or empty matrices.
# 00724	         * In that case, the value of the stride does not really matter, but
# 00725	         * some versions of BLAS insist that:
# 00726	         *  - they are not smaller than the number of elements in the array,
# 00727	         *  - they are not 0.
# 00728	         */
# 00729	        sx_0 = (Nx[0] > 1) ? Sx[0]/type_size : (Nx[1] + 1);
# 00730	        sx_1 = (Nx[1] > 1) ? Sx[1]/type_size : (Nx[0] + 1);
# 00731	        sy_0 = (Ny[0] > 1) ? Sy[0]/type_size : (Ny[1] + 1);
# 00732	        sy_1 = (Ny[1] > 1) ? Sy[1]/type_size : (Ny[0] + 1);
# 00733	        sz_0 = (Nz[0] > 1) ? Sz[0]/type_size : (Nz[1] + 1);
# 00734	        sz_1 = (Nz[1] > 1) ? Sz[1]/type_size : (Nz[0] + 1);
# 00735
# 00736	        switch (type_num)
# 00737	        {
# 00738
# 00739	            case NPY_FLOAT:
# 00740	            {
# 00741
# 00742	                float a = 1.0;
# 00743	                float b = 0.0;
# 00744
# 00745	                float* x = (float*)PyArray_DATA(V3);
# 00746	                float* y = (float*)PyArray_DATA(V5);
# 00747	                float* z = (float*)PyArray_DATA(V1);
# 00748	                char N = 'N';
# 00749	                char T = 'T';
# 00750	                int Nz0 = Nz[0], Nz1 = Nz[1], Nx1 = Nx[1];
# 00751	                //std::cerr << (unit/256) MOD 16 << (unit / 16) MOD 16 << unit MOD 16<< '\n';
# 00752	                //double t0 = time_time();
# 00753	                switch(unit)
# 00754	                {
# 00755	                    case 0x000: sgemm_(&N, &N, &Nz1, &Nz0, &Nx1, &a, y, &sy_0, x, &sx_0, &b, z, &sz_0); break;
# 00756	                    case 0x100: sgemm_(&N, &T, &Nz1, &Nz0, &Nx1, &a, y, &sy_0, x, &sx_1, &b, z, &sz_0); break;
# 00757	                    case 0x010: sgemm_(&T, &N, &Nz1, &Nz0, &Nx1, &a, y, &sy_1, x, &sx_0, &b, z, &sz_0); break;
# 00758	                    case 0x110: sgemm_(&T, &T, &Nz1, &Nz0, &Nx1, &a, y, &sy_1, x, &sx_1, &b, z, &sz_0); break;
# 00759	                    case 0x001: sgemm_(&T, &T, &Nz0, &Nz1, &Nx1, &a, x, &sx_0, y, &sy_0, &b, z, &sz_1); break;
# 00760	                    case 0x101: sgemm_(&N, &T, &Nz0, &Nz1, &Nx1, &a, x, &sx_1, y, &sy_0, &b, z, &sz_1); break;
# 00761	                    case 0x011: sgemm_(&T, &N, &Nz0, &Nz1, &Nx1, &a, x, &sx_0, y, &sy_1, &b, z, &sz_1); break;
# 00762	                    case 0x111: sgemm_(&N, &N, &Nz0, &Nz1, &Nx1, &a, x, &sx_1, y, &sy_1, &b, z, &sz_1); break;
# 00763	                    default: PyErr_SetString(PyExc_ValueError, "some matrix has no unit stride"); {
# 00764	        __failure = 7;
# 00765	        if (!PyErr_Occurred()) {
# 00766	            PyErr_SetString(PyExc_RuntimeError,
# 00767	                "Unexpected error in an Op's C code. "
# 00768	                "No Python exception was set.");
# 00769	            }
# 00770	        goto __label_7;};
# 00771	                };
# 00772	                //fprintf(stderr, "Calling sgemm %i %i %i %i took %f\n", unit, Nz1, Nz0, Nx1, time_time() - t0);
# 00773
# 00774	            }
# 00775	            break;
# 00776	            case NPY_DOUBLE:
# 00777	            {
# 00778
# 00779	                double a = 1.0;
# 00780	                double b = 0.0;
# 00781
# 00782	                double* x = (double*)PyArray_DATA(V3);
# 00783	                double* y = (double*)PyArray_DATA(V5);
# 00784	                double* z = (double*)PyArray_DATA(V1);
# 00785	                char N = 'N';
# 00786	                char T = 'T';
# 00787	                int Nz0 = Nz[0], Nz1 = Nz[1], Nx1 = Nx[1];
# 00788	                //std::cerr << (unit/256) MOD 16 << (unit / 16) MOD 16 << unit MOD 16<< '\n';
# 00789	                //double t0 = time_time();
# 00790	                //fprintf(stderr, "unit=%x N= %i %i %i S = %i %i %i %i %i %i\n", unit,
# 00791	                //Nz1, Nz0, Nx1,
# 00792	                //sy_0, sy_1,
# 00793	                //sx_0, sx_1,
# 00794	                //sz_0, sz_1
# 00795	                //);
# 00796	                switch(unit)
# 00797	                {
# 00798	                    case 0x000: dgemm_(&N, &N, &Nz1, &Nz0, &Nx1, &a, y,
# 00799	                                       &sy_0, x, &sx_0, &b, z, &sz_0); break;
# 00800	                    case 0x100: dgemm_(&N, &T, &Nz1, &Nz0, &Nx1, &a, y,
# 00801	                                       &sy_0, x, &sx_1, &b, z, &sz_0); break;
# 00802	                    case 0x010: dgemm_(&T, &N, &Nz1, &Nz0, &Nx1, &a, y,
# 00803	                                       &sy_1, x, &sx_0, &b, z, &sz_0); break;
# 00804	                    case 0x110: dgemm_(&T, &T, &Nz1, &Nz0, &Nx1, &a, y,
# 00805	                                       &sy_1, x, &sx_1, &b, z, &sz_0); break;
# 00806	                    case 0x001: dgemm_(&T, &T, &Nz0, &Nz1, &Nx1, &a, x,
# 00807	                                       &sx_0, y, &sy_0, &b, z, &sz_1); break;
# 00808	                    case 0x101: dgemm_(&N, &T, &Nz0, &Nz1, &Nx1, &a, x,
# 00809	                                       &sx_1, y, &sy_0, &b, z, &sz_1); break;
# 00810	                    case 0x011: dgemm_(&T, &N, &Nz0, &Nz1, &Nx1, &a, x,
# 00811	                                       &sx_0, y, &sy_1, &b, z, &sz_1); break;
# 00812	                    case 0x111: dgemm_(&N, &N, &Nz0, &Nz1, &Nx1, &a, x,
# 00813	                                       &sx_1, y, &sy_1, &b, z, &sz_1); break;
# 00814	                    default: PyErr_SetString(PyExc_ValueError,
# 00815	                                             "some matrix has no unit stride");
# 00816	                             {
# 00817	        __failure = 7;
# 00818	        if (!PyErr_Occurred()) {
# 00819	            PyErr_SetString(PyExc_RuntimeError,
# 00820	                "Unexpected error in an Op's C code. "
# 00821	                "No Python exception was set.");
# 00822	            }
# 00823	        goto __label_7;};
# 00824	                };
# 00825	                //fprintf(stderr, "Calling dgemm %i %i %i %i took %f\n",
# 00826	                //        unit, Nz1, Nz0, Nx1, time_time()- t0);
# 00827
# 00828	            }
# 00829	            break;
# 00830	        }
# 00831	        __label_7:
# 00832
# 00833	double __DUMMY_7;
# 00834
# 00835	}
# 00836	__label_6:
# 00837
# 00838	        if (V5) {
# 00839	            Py_XDECREF(V5);
# 00840	        }
# 00841
# 00842	    {Py_XDECREF(py_V5);}
# 00843
# 00844	double __DUMMY_6;
# 00845
# 00846	}
# 00847	__label_4:
# 00848
# 00849	        if (V3) {
# 00850	            Py_XDECREF(V3);
# 00851	        }
# 00852
# 00853	    {Py_XDECREF(py_V3);}
# 00854
# 00855	double __DUMMY_4;
# 00856
# 00857	}
# 00858	__label_2:
# 00859
# 00860	    if (!__failure) {
# 00861
# 00862	        {Py_XDECREF(py_V1);}
# 00863	        if (!V1) {
# 00864	            Py_INCREF(Py_None);
# 00865	            py_V1 = Py_None;
# 00866	        }
# 00867	        else if ((void*)py_V1 != (void*)V1) {
# 00868	            py_V1 = (PyObject*)V1;
# 00869	        }
# 00870
# 00871	        {Py_XINCREF(py_V1);}
# 00872
# 00873	        if (V1 && !PyArray_ISALIGNED((PyArrayObject*) py_V1)) {
# 00874	            PyErr_Format(PyExc_NotImplementedError,
# 00875	                         "c_sync: expected an aligned array, got non-aligned array of type %ld"
# 00876	                         " with %ld dimensions, with 3 last dims "
# 00877	                         "%ld, %ld, %ld"
# 00878	                         " and 3 last strides %ld %ld, %ld.",
# 00879	                         (long int) PyArray_TYPE((PyArrayObject*) py_V1),
# 00880	                         (long int) PyArray_NDIM(V1),
# 00881	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 00882	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-3] : -1,
# 00883	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 00884	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-2] : -1,
# 00885	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 00886	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-1] : -1,
# 00887	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 00888	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-3] : -1,
# 00889	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 00890	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-2] : -1,
# 00891	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 00892	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-1] : -1
# 00893	        );
# 00894	            {
# 00895	        __failure = 2;
# 00896	        if (!PyErr_Occurred()) {
# 00897	            PyErr_SetString(PyExc_RuntimeError,
# 00898	                "Unexpected error in an Op's C code. "
# 00899	                "No Python exception was set.");
# 00900	            }
# 00901	        goto __label_2;}
# 00902	        }
# 00903
# 00904	      PyObject* old = PyList_GET_ITEM(storage_V1, 0);
# 00905	      {Py_XINCREF(py_V1);}
# 00906	      PyList_SET_ITEM(storage_V1, 0, py_V1);
# 00907	      {Py_XDECREF(old);}
# 00908	    }
# 00909
# 00910	        if (V1) {
# 00911	            Py_XDECREF(V1);
# 00912	        }
# 00913
# 00914	    {Py_XDECREF(py_V1);}
# 00915
# 00916	double __DUMMY_2;
# 00917
# 00918	}
# 00919
# 00920
# 00921	        if (__failure) {
# 00922	            // When there is a failure, this code puts the exception
# 00923	            // in __ERROR.
# 00924	            PyObject* err_type = NULL;
# 00925	            PyObject* err_msg = NULL;
# 00926	            PyObject* err_traceback = NULL;
# 00927	            PyErr_Fetch(&err_type, &err_msg, &err_traceback);
# 00928	            if (!err_type) {err_type = Py_None;Py_INCREF(Py_None);}
# 00929	            if (!err_msg) {err_msg = Py_None; Py_INCREF(Py_None);}
# 00930	            if (!err_traceback) {err_traceback = Py_None; Py_INCREF(Py_None);}
# 00931	            PyObject* old_err_type = PyList_GET_ITEM(__ERROR, 0);
# 00932	            PyObject* old_err_msg = PyList_GET_ITEM(__ERROR, 1);
# 00933	            PyObject* old_err_traceback = PyList_GET_ITEM(__ERROR, 2);
# 00934	            PyList_SET_ITEM(__ERROR, 0, err_type);
# 00935	            PyList_SET_ITEM(__ERROR, 1, err_msg);
# 00936	            PyList_SET_ITEM(__ERROR, 2, err_traceback);
# 00937	            {Py_XDECREF(old_err_type);}
# 00938	            {Py_XDECREF(old_err_msg);}
# 00939	            {Py_XDECREF(old_err_traceback);}
# 00940	        }
# 00941	        // The failure code is returned to index what code block failed.
# 00942	        return __failure;
# 00943
# 00944	        }
# 00945	    };
# 00946	    }
# 00947
# 00948
# 00949	        static int __struct_compiled_op_d794461d8649d656d8a368a82107fbc7_executor(__struct_compiled_op_d794461d8649d656d8a368a82107fbc7* self) {
# 00950	            return self->run();
# 00951	        }
# 00952
# 00953	        static void __struct_compiled_op_d794461d8649d656d8a368a82107fbc7_destructor(void* executor, void* self) {
# 00954	            delete ((__struct_compiled_op_d794461d8649d656d8a368a82107fbc7*)self);
# 00955	        }
# 00956
# 00957	//////////////////////
# 00958	////  Functions
# 00959	//////////////////////
# 00960	static PyObject * instantiate(PyObject * self, PyObject *argtuple) {
# 00961	  assert(PyTuple_Check(argtuple));
# 00962	  if (4 != PyTuple_Size(argtuple)){
# 00963	     PyErr_Format(PyExc_TypeError, "Wrong number of arguments, expected 4, got %i", (int)PyTuple_Size(argtuple));
# 00964	     return NULL;
# 00965	  }
# 00966	  __struct_compiled_op_d794461d8649d656d8a368a82107fbc7* struct_ptr = new __struct_compiled_op_d794461d8649d656d8a368a82107fbc7();
# 00967	  if (struct_ptr->init( PyTuple_GET_ITEM(argtuple, 0),PyTuple_GET_ITEM(argtuple, 1),PyTuple_GET_ITEM(argtuple, 2),PyTuple_GET_ITEM(argtuple, 3) ) != 0) {
# 00968	    delete struct_ptr;
# 00969	    return NULL;
# 00970	  }
# 00971	  PyObject* thunk = PyCObject_FromVoidPtrAndDesc((void*)(&__struct_compiled_op_d794461d8649d656d8a368a82107fbc7_executor), struct_ptr, __struct_compiled_op_d794461d8649d656d8a368a82107fbc7_destructor);
# 00972	  return thunk; }
# 00973
# 00974	//////////////////////
# 00975	////  Module init
# 00976	//////////////////////
# 00977	static PyMethodDef MyMethods[] = {
# 00978		{"instantiate", instantiate, METH_VARARGS, "undocumented"} ,
# 00979		{NULL, NULL, 0, NULL}
# 00980	};
# 00981	PyMODINIT_FUNC initd794461d8649d656d8a368a82107fbc7(void){
# 00982	   import_array();
# 00983	   (void) Py_InitModule("d794461d8649d656d8a368a82107fbc7", MyMethods);
# 00984	}
# 00985
# Problem occurred during compilation with the command line below:
# C:\TDM-GCC-64\bin\g++.exe -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -march=sandybridge -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -mno-sse4a -mcx16 -msahf -mno-movbe -maes -mno-sha -mpclmul -mpopcnt -mno-abm -mno-lwp -mno-fma -mno-fma4 -mno-xop -mno-bmi -mno-bmi2 -mno-tbm -mavx -mno-avx2 -msse4.2 -msse4.1 -mno-lzcnt -mno-rtm -mno-hle -mno-rdrnd -mno-f16c -mno-fsgsbase -mno-rdseed -mno-prfchw -mno-adx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mno-clflushopt -mno-xsavec -mno-xsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mno-clwb -mno-pcommit --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=3072 -mtune=sandybridge -D NPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -IC:\Users\Yanjie\Anaconda\lib\site-packages\numpy\core\include -IC:\Users\Yanjie\Anaconda\include -IC:\Users\Yanjie\Anaconda\lib\site-packages\theano\gof -o C:\Users\Yanjie\AppData\Local\Theano\compiledir_Windows-10-10.0.10586-Intel64_Family_6_Model_42_Stepping_7_GenuineIntel-2.7.11-64\tmpemiacq\d794461d8649d656d8a368a82107fbc7.pyd C:\Users\Yanjie\AppData\Local\Theano\compiledir_Windows-10-10.0.10586-Intel64_Family_6_Model_42_Stepping_7_GenuineIntel-2.7.11-64\tmpemiacq\mod.cpp -LC:\Users\Yanjie\Anaconda\libs -LC:\Users\Yanjie\Anaconda -lpython27 -lblas
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-1-6acc39f4d84f> in <module>()
#       8 np_end = time.time()
#       9 X,Y = theano.tensor.matrices('XY')
# ---> 10 mf = theano.function([X,Y],X.dot(Y))
#      11 t_start = time.time()
#      12 tAB = mf(A,B)
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\compile\function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     315                    on_unused_input=on_unused_input,
#     316                    profile=profile,
# --> 317                    output_keys=output_keys)
#     318     # We need to add the flag check_aliased inputs if we have any mutable or
#     319     # borrowed used defined inputs
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\compile\pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     477                          accept_inplace=accept_inplace, name=name,
#     478                          profile=profile, on_unused_input=on_unused_input,
# --> 479                          output_keys=output_keys)
#     480
#     481
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\compile\function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1775                    on_unused_input=on_unused_input,
#    1776                    output_keys=output_keys).create(
# -> 1777             defaults)
#    1778
#    1779     t2 = time.time()
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\compile\function_module.pyc in create(self, input_storage, trustme, storage_map)
#    1639             theano.config.traceback.limit = 0
#    1640             _fn, _i, _o = self.linker.make_thunk(
# -> 1641                 input_storage=input_storage_lists, storage_map=storage_map)
#    1642         finally:
#    1643             theano.config.traceback.limit = limit_orig
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\gof\link.pyc in make_thunk(self, input_storage, output_storage, storage_map)
#     688         return self.make_all(input_storage=input_storage,
#     689                              output_storage=output_storage,
# --> 690                              storage_map=storage_map)[:3]
#     691
#     692     def make_all(self, input_storage, output_storage):
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\gof\vm.pyc in make_all(self, profiler, input_storage, output_storage, storage_map)
#    1035                                                  storage_map,
#    1036                                                  compute_map,
# -> 1037                                                  no_recycling))
#    1038                 if not hasattr(thunks[-1], 'lazy'):
#    1039                     # We don't want all ops maker to think about lazy Ops.
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\gof\op.pyc in make_thunk(self, node, storage_map, compute_map, no_recycling)
#     963             try:
#     964                 return self.make_c_thunk(node, storage_map, compute_map,
# --> 965                                          no_recycling)
#     966             except (NotImplementedError, utils.MethodNotDefined):
#     967                 logger.debug('Falling back on perform')
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\gof\op.pyc in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     877         logger.debug('Trying CLinker.make_thunk')
#     878         outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 879                                 output_storage=node_output_storage)
#     880         fill_storage, node_input_filters, node_output_filters = outputs
#     881
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\gof\cc.pyc in make_thunk(self, input_storage, output_storage, storage_map, keep_lock)
#    1205         cthunk, in_storage, out_storage, error_storage = self.__compile__(
#    1206             input_storage, output_storage, storage_map,
# -> 1207             keep_lock=keep_lock)
#    1208
#    1209         res = _CThunk(cthunk, init_tasks, tasks, error_storage)
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\gof\cc.pyc in __compile__(self, input_storage, output_storage, storage_map, keep_lock)
#    1150                                     output_storage,
#    1151                                     storage_map,
# -> 1152                                     keep_lock=keep_lock)
#    1153         return (thunk,
#    1154                 [link.Container(input, storage) for input, storage in
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\gof\cc.pyc in cthunk_factory(self, error_storage, in_storage, out_storage, storage_map, keep_lock)
#    1600         else:
#    1601             module = get_module_cache().module_from_key(
# -> 1602                 key=key, lnk=self, keep_lock=keep_lock)
#    1603
#    1604         vars = self.inputs + self.outputs + self.orphans
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\gof\cmodule.pyc in module_from_key(self, key, lnk, keep_lock)
#    1172             try:
#    1173                 location = dlimport_workdir(self.dirname)
# -> 1174                 module = lnk.compile_cmodule(location)
#    1175                 name = module.__file__
#    1176                 assert name.startswith(location)
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\gof\cc.pyc in compile_cmodule(self, location)
#    1511                 lib_dirs=self.lib_dirs(),
#    1512                 libs=libs,
# -> 1513                 preargs=preargs)
#    1514         except Exception as e:
#    1515             e.args += (str(self.fgraph),)
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\theano\gof\cmodule.pyc in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2224             # difficult to read.
#    2225             raise Exception('Compilation failed (return status=%s): %s' %
# -> 2226                             (status, compile_stderr.replace('\n', '. ')))
#    2227         elif config.cmodule.compilation_warning and compile_stderr:
#    2228             # Print errors just below the command line.
#
# Exception: ('The following error happened while compiling the node', Dot22(X, Y), '\n', "Compilation failed (return status=1): C:/TDM-GCC-64/bin/../lib/gcc/x86_64-w64-mingw32/5.1.0/libblas.a(xerbla.o):xerbla.f:(.text+0x55): undefined reference to `_gfortran_st_write'\r. C:/TDM-GCC-64/bin/../lib/gcc/x86_64-w64-mingw32/5.1.0/libblas.a(xerbla.o):xerbla.f:(.text+0x5f): undefined reference to `_gfortran_string_len_trim'\r. C:/TDM-GCC-64/bin/../lib/gcc/x86_64-w64-mingw32/5.1.0/libblas.a(xerbla.o):xerbla.f:(.text+0x76): undefined reference to `_gfortran_transfer_character_write'\r. C:/TDM-GCC-64/bin/../lib/gcc/x86_64-w64-mingw32/5.1.0/libblas.a(xerbla.o):xerbla.f:(.text+0x87): undefined reference to `_gfortran_transfer_integer_write'\r. C:/TDM-GCC-64/bin/../lib/gcc/x86_64-w64-mingw32/5.1.0/libblas.a(xerbla.o):xerbla.f:(.text+0x8f): undefined reference to `_gfortran_st_write_done'\r. C:/TDM-GCC-64/bin/../lib/gcc/x86_64-w64-mingw32/5.1.0/libblas.a(xerbla.o):xerbla.f:(.text+0x98): undefined reference to `_gfortran_stop_string'\r. collect2.exe: error: ld returned 1 exit status\r. ", '[Dot22(X, Y)]')
